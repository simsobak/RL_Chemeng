# %%
#MATLAB CODE
'''
function [sys,x0,str,tss]=cstr1(t,x,u,flag,Param,X_ss)

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

%
% An s-function to model a simple CSTR with first order kinetics and the following
% reaction ( A + D --> B) and ( A --> C) with a variable height well mixed vessel.  The equations that describe
% the system are:
% dV/dt  = F_in - F
% R1     = k1*Cd*Ca
% R2     = k2*Ca
% dCa/dt = F_in/V*(Ca_in-Ca)-R1-R2
% dCb/dt = F_in/V*(Cb_in-Cb)+R1
% dCc/dt = F_in/V*(Cc_in-Cc)+R2
% dCd/dt = F_in/V*(Cd_in-Cd)-R1
% dT /dt = - T/V*(F_in - F) + 1/V *(F_in*T_in - F*T) + 1/d/Cp*(-DH1)*R1+ 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*U*A*(Tc - T)

%================================================================================

switch flag,

case 0,	% Initialize the states and sizes
   [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);
   
        % ****************
  	%  Outputs
  	% ****************   
     
case 3,   % Calculate the outputs

sys = mdlOutputs(t,x,u,Param);
   
   % ****************
   % Update
   % ****************
case 1,	% Obtain derivatives of states
   
   sys = mdlDerivatives(t,x,u,Param);

otherwise,
   sys = [];
end

% ******************************************
% Sub-routines or Functions
% ******************************************

% ******************************************
% Initialization
% ******************************************
function [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

% This handles initialization of the function.
% Call simsize of a sizes structure.
sizes = simsizes;
sizes.NumContStates  = 6;     % continuous states
sizes.NumDiscStates  = 0;     % discrete states
sizes.NumOutputs     = 7;     % outputs of model (manipulated variables)
sizes.NumInputs      = 9;     % inputs of model [r;Y;Ud]
sizes.DirFeedthrough = 1;     % System is not causal, there is explicit dependence of outputs on inputs.
sizes.NumSampleTimes = 1;     %
sys = simsizes(sizes);        %
x0  = X_ss;                   % Initialize the discrete states (inputs).
str = [];	                  % set str to an empty matrix.
tss = [0,0];	              % sample time: [period, offset].

% ******************************************
%  Outputs
% ******************************************
function sys = mdlOutputs(t,x,u,Param);

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;


SWITCH = Param(1);
% entering flow
F_in = u(1)+5;
% exiting volumetric flow
F    =u(7)+5;

% outputs:
sys(1) = x(1);
sys(2) = F;
sys(3) = x(2);
sys(4) = x(3);
sys(5) = x(4);
sys(6) = x(5);
sys(7) = x(6);
% sys(8) = (PB*F*x(3)+PC*F*x(5)-PA*F*(u(2)+1)-PD*F*(u(8)+1)-PHEAT*(UA*((u(4)+200)-x(4))));

% ******************************************
% Derivatives
% ******************************************
function sys = mdlDerivatives(t,x,u,Param)

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

% External Parameters:
% [0;1;-1000;1;1;25;21500;10;-1000;91500],

SWITCH = Param(1);
k01    = u(9)+1;
DH1    = Param(3);
d      = Param(4);
Cp     = Param(5);
UA     = Param(6);
EA1    = Param(7);
k02    = Param(8);
DH2    = Param(9);
EA2    = Param(10);

% Inputs (Disturbances):
% entering flow
F_in = u(1)+5;
% Entering concentration of A:
Ca   = u(2)+1;
% Entering concentration of B:
Cb   = u(3);
% Coolant Temperature in Jacket:
Tc   = u(4)+200;
% Entering concentration of C:
Cc   = u(5);

% Inputs (Manipulated Variables):
% exiting volumetric flow
F    = u(7)+5;
% Feed Temperature
T_in = u(6)+140;

% Entering Concentration of D
Cd = u(8)+1;

% Derivatives:
V = x(1);
k1 = k01 * exp (-EA1/8.314/(1.8*x(4)+1000));
k2 = k02 * exp (-EA2/8.314/(2.8*x(4)+1000));
R1 = k1*x(6)*x(2);
R2 = k2*x(2);
sys(1) = F_in - F;
sys(2) = F_in/V*(Ca-x(2))-R1-R2;
sys(3) = F_in/V*(Cb-x(3))+R1;
sys(4) = - x(4)/V*(F_in - F) + 1/V *(F_in*T_in - F*x(4)) + 1/d/Cp*(-DH1)*R1 + 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*UA*(Tc - x(4));
sys(5) = F_in/V*(Cc-x(5))+R2;
sys(6) = F_in/V*(Cd-x(6))-R1;
'''

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def cstr_model(x,t,parameters):
    #reaction ( A + D --> B) and ( A --> C)
    k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in  = parameters
    
   
    
    k1 =k01 * np.exp (-EA1/8.314/(1.8*x[3]+1000))        
    k2 =k02 * np.exp (-EA2/8.314/(2.8*x[3]+1000))        
    
    
  
    V= x[0]
    Ca= x[1]
    Cb= x[2]
    T= x[3]
    Cc= x[4]
    Cd= x[5]
    
    R1 = k1 *Ca*Cd
    R2 = k2*Ca
    
    
    dVdt  =  F_in-F
    dCadt = (F_in/V*(Ca_in-Ca))-R1-R2
    
    dCbdt =(F_in/V*(Cb_in-Cb))+R1
    
    dTdt = - T/V*(F_in - F) + 1/V *(F_in*T_in - F*T) + 1/d/Cp*(-DH1)*R1 + 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*UA*(Tc - T)
    
    dCcdt = (F_in/V*(Cc_in- Cc))+R2
    dCddt=(F_in/V*(Cd_in-Cd))-R1
   
    
    
    return [  dVdt, dCadt,dCbdt,dTdt,dCcdt,dCddt] #COnc out

# %%
def pp_random_walk():
    dims = 1
    step_n = 4000
    step_set = [-1, 0, 1]
    origin = np.zeros((1,dims))
    # Simulate steps in 1D
    step_shape = (step_n,dims)
    steps = np.random.choice(a=step_set, size=step_shape)
    path = np.concatenate([origin, steps]).cumsum(0)
    
    return path
def av(path, fluc_price):
    
 
    x1 = path[:1000]
    x2 = path[1000:2000]
    x3 = path[2000:3000]
    x4 = path[3000:]
    catch = [x1,x2,x3,x4]
    con = []
    for i in range(len(catch)):
        y = 0
        for i2 in range(len(catch[i])):
            y += catch[i][i2]
        av = y/len(catch[i])
        con.append(av)
    
    #print(con)

    maxr = 0
    for i in range(len(con)):
        if abs(maxr) < abs(con[i]):
            maxr = con[i]
    #print(maxr)
    
    if fluc_price > maxr:
        range_ = fluc_price/maxr 
        pl = np.ones(4000)
        pl[:1000] = (con[0] *range_ )
        pl[1000:2000] = (con[1]*range_ )
        pl[2000:3000] = (con[2]*range_ )
        pl[3000:] = (con[3]*range_ )
    else:
        print(maxr)
        maxr = maxr*-1
        range_ =fluc_price/maxr #maxr /fluc_price
        pl = np.ones(4000)
        pl[:1000] = (con[0] *range_ )
        pl[1000:2000] = (con[1]*range_ )
        pl[2000:3000] = (con[2]*range_ )
        pl[3000:] = (con[3]*range_ )
    
        
    return pl

# %%
def av1(path, fluc_price):
    
    x1 = path[:1333]
    x2 = path[1333:2666]
    x3 = path[2666:]
 
    catch = [x1,x2,x3]
    con = []
    for i in range(len(catch)):
        y = 0
        for i2 in range(len(catch[i])):
            y += catch[i][i2]
        av = y/len(catch[i])
        con.append(av)
    
    #print(con)

    maxr = 0
    for i in range(len(con)):
        if abs(maxr) < abs(con[i]):
            maxr = con[i]
    #print(maxr)
    
    if fluc_price > maxr:
        range_ = fluc_price/maxr
        pl = np.ones(4000)
        pl[:1333] = (con[0] *range_ )
        pl[1333:2666] = (con[1]*range_ )
        pl[2666:] = (con[2]*range_ )
      
    else:
        #maxr = maxr*-1
        range_ =maxr /fluc_price
        pl = np.ones(4000)
        pl[:1333] = (con[0] /range_ )
        pl[1333:2666] = (con[1]/range_ )
        pl[2666:] = (con[2] /range_ )
       
    
        
    return pl

# %%
import numpy as np
import random

# %%
class ChemEnv():
    def __init__(self,disturbance): #initalise with the disturbances and add them to simulate_react at certain timesteps
       
       
        self.T_disturbance = disturbance[0]
        self.Ca_disturbance = disturbance[4]
        self.p_disturbance = [disturbance[1],disturbance[2],disturbance[3]]
        
        self.state = None
        self.done = False
        
        #self.episode_length= 4000
    def step(self, action,episode_timestep,old_inputs,concs_T_V,prices,bounds,total_epi,epi): #what we do when we take a step
        new_inputs = simulate_inputs(self.reset,action,episode_timestep,old_inputs, self.T_disturbance, self.Ca_disturbance,bounds)
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = new_inputs
        
        new_concs_T_V = simulate_react(self.reset,episode_timestep,new_inputs,concs_T_V)
        
        self.current_V = new_concs_T_V[0][episode_timestep]
        self.current_Ca = new_concs_T_V[1][episode_timestep]
        self.current_Cb = new_concs_T_V[2][episode_timestep]
        self.current_T = new_concs_T_V[3][episode_timestep]
        self.current_Cc = new_concs_T_V[4][episode_timestep]
        self.current_Cd = new_concs_T_V[5][episode_timestep]
        profitt, Ca_p, Cb_p, Cc_p = profit_(new_concs_T_V,prices,episode_timestep, self.p_disturbance, new_inputs,total_epi,epi)
        
        self.episode_timestep = episode_timestep
        self.current_Tc = Tc[episode_timestep]
        self.current_T_in = T_in[episode_timestep]
        self.current_Ca_price = Ca_p
        self.current_Cb_price = Cb_p
        self.current_Cc_price = Cc_p
        self.current_Ca_in = Ca_in[episode_timestep]
        self.current_Cd_in = Cd_in[episode_timestep]
        self.current_F_in = F_in[episode_timestep]
   
        if self.episode_timestep == int(3998):
            self.done = True
            print(self.reward)
        else:
            self.done = False
            profit =profitt
        
        done = self.done
        self.reward += profitt
        self.reward1 = profitt
      
        self.state = ( new_concs_T_V,new_inputs, profitt  )
        #set placeholder for info
        info = {}
        
        #return step information
        return self.state, self.reward1, done, info
        
    def render(self): #visualisations
        #implement visualisation
        #get all current values,write to file and visualise in different python script
        with open("ml2txt.txt", "a") as myfile:
            myfile.write(f'\n{self.current_Tc},{self.current_Ca},{self.current_Cb},{self.current_T},{self.current_Cc},{self.current_Cd},{self.current_T_in},{self.current_Ca_price},{self.current_Cb_price},{self.current_Cc_price}, {self.reward},{self.current_Ca_in},{self.current_Cd_in},{self.current_F_in}')
            myfile.close()
        #pass
    def reset(self): #how we reset our enviroment
        self.reward =0
        self.reward1 =0
        input_reset = simulate_inputs(True,1,1,1,1,1,1  )
        concs_T_V = simulate_react(True, 0,input_reset,1)
        V, Ca, Cb, T, Cc, Cd = concs_T_V
        #clear contents in text file
        file = open("ml2txt.txt","r+")
        file.truncate(0)
        file.close()
        self.state = [[V, Ca, Cb,T,Cc, Cd], input_reset]
        return self.state

# %%
def simulate_inputs(reset,action, timestep, inputs,disturbance, disturbance_, bounds):
    t = np.linspace(0,4000,4000)#starting,end,how many points(from 0 to end) i used 4000 because number of episodes per batch

    if reset == True: 

        

        k01=np.ones(len(t))*1
        DH1=np.ones(len(t))*-1000
        d =np.ones(len(t))*1
        Cp=np.ones(len(t))*1
        UA=np.ones(len(t))*25
        EA1=np.ones(len(t))*21500
        k02=np.ones(len(t))*10
        DH2=np.ones(len(t))*-1000
        EA2=np.ones(len(t))*91500
        F_in=np.ones(len(t))*5
        Ca_in=np.ones(len(t))*1
        Cb_in =np.ones(len(t))*0
        Tc = np.ones(len(t))*200
        Cc_in = np.ones(len(t))*0
        F = np.ones(len(t))*5
        T_in = np.ones(len(t))*140
        Cd_in = np.ones(len(t))*1
        return [k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in]
    else:
       
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
     
        #print(action[0]) 
        Ca_in[timestep:] = 1  + disturbance_[timestep] 
        Cd_in[timestep:] = min(bounds[2],max(bounds[3], Cd_in[timestep-1:timestep] + action[2][0])) 
        Tc[timestep:] = min(bounds[4],max(bounds[5],Tc[timestep-1:timestep] + (action[0][0]))) 
        F_in[timestep:] = min(bounds[0],max(bounds[1],F_in[timestep-1:timestep] + (action[1][0])))
        F[timestep: ] =  F_in[timestep:]
        T_in[timestep:] = 140 +  disturbance[timestep] 
        return [k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in]

# %%
def simulate_react(reset,episode_timestep,inputs,concs_T_V):
    t = np.linspace(0,4000,4000)
    if reset == True:
        i = episode_timestep
        V0 = 100
        Ca0 = 0.3038
        Cb0 = 0.534
        T0 = 306
        Cc0 = 0.162
        Cd0 = 0.466
        V  = np.ones(len(t))*V0
        Ca = np.ones(len(t))*Ca0
        Cb = np.ones(len(t))*Cb0
        T  = np.ones(len(t))*T0
        Cc = np.ones(len(t))*Cc0
        Cd = np.ones(len(t))*Cd0
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
        input_ = [k01[i],DH1[i],d[i],Cp[i],UA[i],EA1[i],k02[i],DH2[i],EA2[i],F_in[i],Ca_in[i],Cb_in[i],Tc[i],Cc_in[i],F[i],T_in[i],Cd_in[i] ]
       
        x0 = [V0,Ca0,Cb0,T0,Cc0,Cd0]
        ts = [i, i+1]
        y = odeint(cstr_model,x0,ts,args=(input_,))
        # Store results
        V[i+1]  = y[-1][0]
        Ca[i+1] = y[-1][1]
        Cb[i+1] = y[-1][2] 
        T[i+1]  = y[-1][3]
        Cc[i+1]  = y[-1][4]
        Cd[i+1]  = y[-1][5]
        dChangedt = y[-1]
        concs_T_V = V,Ca,Cb,T,Cc,Cd 
        return concs_T_V #[dChangedt]
    else:
        i = episode_timestep
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
        input_ = [k01[i],DH1[i],d[i],Cp[i],UA[i],EA1[i],k02[i],DH2[i],EA2[i],F_in[i],Ca_in[i],Cb_in[i],Tc[i],Cc_in[i],F[i],T_in[i],Cd_in[i] ]
        
        V,Ca,Cb,T,Cc,Cd = concs_T_V
        x = [V[i],Ca[i],Cb[i],T[i],Cc[i],Cd[i]]
        ts = [i, i+1]
        y = odeint(cstr_model,x,ts,args=(input_,))
        # Store results
        V[i+1]  = y[-1][0]
        Ca[i+1] = y[-1][1]
        Cb[i+1] = y[-1][2] 
        T[i+1]  = y[-1][3]
        Cc[i+1]  = y[-1][4]
        Cd[i+1]  = y[-1][5]
        dChangedt = y[-1]
        concs_T_V = V,Ca,Cb,T,Cc,Cd  
        
        return concs_T_V

# %%
def profit_(concs_T_V, prices, episode_timestep, price_disturbance, new_inputs,total_epi,epi):
    i = episode_timestep
    V,Ca,Cb,T,Cc,Cd = concs_T_V
    price_Ca,price_Cb,price_Cc,price_Cd,price_heat= prices
    disturb_Ca, disturb_Cb, disturb_Cc  =price_disturbance
    k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = new_inputs
    
    F_in = F_in[i]
    UA =25
    Ca_in = Ca_in[i]
    Cd_in = Cd_in[i]
    Cb = Cb[ i]
    T = T[i]

    Cc = Cc[ i]
    price_Ca = min(7,max(price_Ca + disturb_Ca[i],5))
    price_Cb = min(20,max(12,price_Cb + disturb_Cb[i]))
    price_Cc = min(19,max(10,price_Cc + disturb_Cc[i]))
    
    temp_cost = (price_heat*UA*(Tc[i]-T))
    Ca_cost = (price_Ca* Ca_in)
    Cd_cost = (price_Cd* Cd_in)
    delta_Tc = 200-Tc[i]
    penalty_T1 = (100*tf.math.tanh(T-800))+100  
    penalty_T2 = (100*tf.math.tanh(-T+100))+100 
    penalty_CC = (100*tf.math.tanh(-Cc+0.01))+100
    penalty_CB = (100*tf.math.tanh(-Cb+0.01))+100
    total_penalty =  penalty_T1 +  penalty_T2  + penalty_CC+ penalty_CB
 

    
    
    profit = F_in*(((Cb*price_Cb)+ (Cc*price_Cc)) -((price_Ca* Ca_in)+(price_Cd* Cd_in))) + temp_cost
    
    ir = 0.1
    beg_ = 0.1
    power = (epi/total_epi)*10
    discount_ = beg_*((1+ir)**power)
    
   
    profit_ = (profit)-(discount_*total_penalty)
   
    return [profit_,price_Ca,price_Cb,price_Cc]

# %%
def disturbance_generator(episode, number_of_episodes):
    prices = [5, 12, 19, 2, 0.001]
    i1 = 0.5
    i2 = 0.1
    i3 = 0.3
    
    power = (episode/number_of_episodes)*10
    
    ca_disturb_bound = 2*((1+i2)**power)
    ca_disturb_bound = min(ca_disturb_bound,2)
    cb_disturb_bound = 6*((1+i1)**power)
    cb_disturb_bound = min(cb_disturb_bound,8)
    cc_disturb_bound = 6*((1+i1)**power)
    cc_disturb_bound = min(cc_disturb_bound,9)
    cc_disturb_bound *=-1
    ca_in_disturb_bound =0.15*((1+i3)**power)
    ca_in_disturb_bound = min( ca_in_disturb_bound,0.4) #0.4
    ###T-disturbance
    sr=0.05
    ts = 1.0/sr
    t = np.arange(0,80000,ts)
    freq = 0.00004 
    y = 60*np.sin(2*np.pi*freq*t)
    T_disturb = y
    #######Ca_disturb price
    t1 = pp_random_walk()
    Ca_disturb_price = av1(t1,ca_disturb_bound) #2 ca_disturb_bound
    ######Cb_disturb price
    t2 = pp_random_walk()
    Cb_disturb_price = av1(t2,cb_disturb_bound) #8
    ######Cc_disturb price
    t3 = pp_random_walk()
    Cc_disturb_price = av1(t3, cc_disturb_bound ) #-9
    ######Ca_in disturb
    t4 = pp_random_walk()
    Ca_in_disturb = av(t4, ca_in_disturb_bound)
    
    disturbs = [T_disturb,Ca_disturb_price,Cb_disturb_price,Cc_disturb_price,Ca_in_disturb]
    
    return disturbs

# %%
def test_generator(disturb):
    ############################################
    T_disturb = disturb[0]
    Ca_disturb_price = disturb[1]
    Cb_disturb_price = disturb[2]
    Cc_disturb_price = disturb[3]
    Ca_in_disturb = disturb[4]
    #############################################
    Ca_in_disturb[0:500] = 0 #1000
    Ca_in_disturb[500:2000] = 0.4#0.3 1000-2200
    Ca_in_disturb[2000:] = 0.05#0.1 2200
    #############################################
    Ca_disturb_price[0:1500] = 0 #1200
    Ca_disturb_price[1500:]=1.5#2 1200
    #############################################
    Cb_disturb_price[0:1100]= 0
    Cb_disturb_price[1100:]= 5#8
    #############################################
    Cc_disturb_price[0:1000]= 0 #420
    Cc_disturb_price[1000:]= -8#-9 #420
    ############################################
    
    return [T_disturb,Ca_disturb_price,Cb_disturb_price,Cc_disturb_price,Ca_in_disturb]

# %%
def bounds_generator(episode, number_of_episodes,training):
    if training:
        upper_F = 7
        lower_F = 3
        upper_Cd = 0.6
        lower_Cd = 0.2
        upper_T = 375
        lower_T = 350
        upper_r = 0.5
        upper_r1 = 0.7
        lower_r = 0.6

        power = (episode/number_of_episodes)*10
        upper_F = upper_F*((1+upper_r)**power)
        upper_F = min(25,upper_F)
        upper_Cd = upper_Cd*((1+upper_r)**power)
        upper_Cd = min(5,upper_Cd)
        upper_T = upper_T*((1+upper_r)**power)
        upper_T = min(550,upper_T)
        #################################################
        lower_F = lower_F*((1+lower_r)**-power)
        lower_F = max(1,lower_F)
        lower_Cd = lower_Cd*((1+lower_r)**-power)
        lower_Cd = max(0.001,lower_Cd)
        lower_T =lower_T*((1+lower_r)**-power)
        lower_T = max(280,lower_T)
        
        return [upper_F,lower_F,upper_Cd,lower_Cd,upper_T,lower_T]
    else:
        return [25,1,5,0.001,550,280]

# %%
#Appendix 3
import import_ipynb
from ipynb.fs.full.S_A_C_11 import Agent11
from ipynb.fs.full.S_A_C_12 import Agent12
from ipynb.fs.full.S_A_C_13 import Agent13
agent1 = Agent11()
agent2 = Agent12()
agent3 = Agent13()
score_catcher = []
avg_catcher = []
agg = []
import numpy as np
# Out:
# importing Jupyter notebook from Experience_Replay.ipynb

# %%
#Appendix 4
from ipynb.fs.full.S_A_C_14 import Agent14
from ipynb.fs.full.S_A_C_15 import Agent15
from ipynb.fs.full.S_A_C_16 import Agent16
agent = Agent14()
agent2 = Agent15()
agent3 = Agent16()
score_catcher = []
avg_catcher = []
agg = []

# %%
#!pip install ipynb

# %%
import math as m
agent1 = Agent11()
agent2 = Agent12()
agent3 = Agent13()
score_catcher = []
avg_catcher = []
agg = []

# %%
import tensorflow as tf

# %%
agent1.load_models()
agent2.load_models()
agent3.load_models()
prices = [5, 12, 19, 2, 0.001] #Ca,Cb,Cc,Cd,Energy
r = []
r1 = []
score = 0
max_ = 0
number_episodes =70
alpha_beg = 0.99
ir1 = 0.01
ir2 = 0.01
ir3 = 0.01
obs_holder = []
for epi in range(number_episodes):
    bounds = bounds_generator(epi,number_episodes,False)
    if epi == 0:
        disturbs = disturbance_generator(epi,number_episodes)
        test_disturb = test_generator(disturbs)
        env = ChemEnv(test_disturb)
        env = ChemEnv(disturbs)
    elif epi % 5 == 0:
        disturbs = disturbance_generator(epi,number_episodes)
        test_disturb = test_generator(disturbs)
        env = ChemEnv(test_disturb)
        #env = ChemEnv(disturbs) #new disturbances
    else:
        pass #same disturbances as before
    timesteps = 4000
    current_state =env.reset()
    obs = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5],current_state[1][-2],(5+disturbs[1][0])/5,(12+disturbs[2][0])/12,(19+disturbs[3][0])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]])#.astype('float32') 
    start = True
    score = 0
    starter_ = np.ones(12)
    obs_holder = []
    obs_holder.append(starter_)
    obs_holder.append(obs)
    alpha1 = max(0.8, alpha_beg*((1+ir1)**((-epi/number_episodes)*10)))
    alpha2 = max(0.8, alpha_beg*((1+ir2)**((-epi/number_episodes)*10)))
    alpha3 = max(0.8, alpha_beg*((1+ir3)**((-epi/number_episodes)*10)))
    for timestep in range(1,timesteps-1):
        action1 = agent1.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
        action2 = agent2.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
        action3 = agent3.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
        step = env.step([action1,action2,action3],timestep,current_state[1],current_state[0],prices,bounds,number_episodes,epi)
        env.render()
        current_state = [step[0][0],step[0][1]]

        obs_ = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5], current_state[1][-2],(5+disturbs[1][timestep])/5, (12+disturbs[2][timestep])/12,(19+disturbs[2][timestep])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]]) #current_state[1][-2]#.astype('float32')
        s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12  = obs
        obs_r = np.array([s1[timestep], s2[timestep], s3[timestep]/1000, s4[timestep], s5[timestep],s6[timestep]/1000,s7,s8,s9,s10[timestep]/1000,s11[timestep],s12[timestep]])
        s1a,s2a,s3a,s4a,s5a,s6a,s7a,s8a,s9a, s10a,s11a,s12a  = obs_
        obs_r_ = np.array([s1a[timestep], s2a[timestep], s3a[timestep]/1000, s4a[timestep], s5a[timestep],s6a[timestep]/1000,s7a,s8a,s9a,s10a[timestep]/1000,s11a[timestep],s12a[timestep]])
        reward = step[1]
        done = step[2]
        filler_ = np.ones(12)
        obs_r = np.concatenate([obs_r,filler_])
        obs_r_ = np.concatenate([obs_r_,filler_])
        agent1.remember(obs_r, action1, reward, obs_r_, done)
        agent2.remember(obs_r, action2, reward, obs_r_, done)
        agent3.remember(obs_r, action3, reward, obs_r_, done)
        obs_holder.clear()
        obs_holder.append(obs)
        obs_holder.append(obs_)
        obs = obs_
        score += reward
        start = False
        r.append(score)
       
    
    r1.append(score)
    avg_s = np.mean(r[-4000:])
    avg_catcher.append(avg_s)
# Out:
# [17.353]
# C:\Users\simso\AppData\Local\Temp\ipykernel_33564\3312839076.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   obs = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5],current_state[1][-2],(5+disturbs[1][0])/5,(12+disturbs[2][0])/12,(19+disturbs[3][0])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]])#.astype('float32')
# C:\Users\simso\AppData\Local\Temp\ipykernel_33564\3312839076.py:46: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   obs_ = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5], current_state[1][-2],(5+disturbs[1][timestep])/5, (12+disturbs[2][timestep])/12,(19+disturbs[2][timestep])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]]) #current_state[1][-2]#.astype('float32')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 12>()
#      39 action1 = agent1.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
#      40 action2 = agent2.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
# ---> 41 action3 = agent3.choose_action([obs_holder[0],obs_holder[1]],timestep,start)
#      42 step = env.step([action1,action2,action3],timestep,current_state[1],current_state[0],prices,bounds,number_episodes,epi)
#      43 env.render()
#
# File ~\Downloads\RL\S_A_C_16.ipynb:186, in choose_action(self, observation, epi_time, start)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [
#       8     {
#       9      "name": "stdout",
#      10      "output_type": "stream",
#      11      "text": [
#      12       "importing Jupyter notebook from Experience_Replay.ipynb\n"
#      13      ]
#      14     }
#      15    ],
#      16    "source": [
#      17     "import os\n",
#      18     "import numpy as np\n",
#      19     "import tensorflow as tf\n",
#      20     "import tensorflow.keras as keras\n",
#      21     "import tensorflow_probability as tfp\n",
#      22     "from tensorflow.keras.layers import Dense, LeakyReLU, LSTM\n",
#      23     "import import_ipynb\n",
#      24     "import Experience_Replay\n",
#      25     "from tensorflow.keras.optimizers import Adam\n",
#      26     "from tensorflow.keras.optimizers.schedules import ExponentialDecay"
#      27    ]
#      28   },
#      29   {
#      30    "cell_type": "code",
#      31    "execution_count": 2,
#      32    "metadata": {},
#      33    "outputs": [],
#      34    "source": [
#      35     "#!pip install --upgrade tensorflow"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": 3,
#      41    "metadata": {},
#      42    "outputs": [],
#      43    "source": [
#      44     "#import tensorflow as tf\n",
#      45     "#tf.version.VERSION"
#      46    ]
#      47   },
#      48   {
#      49    "cell_type": "code",
#      50    "execution_count": 4,
#      51    "metadata": {},
#      52    "outputs": [],
#      53    "source": [
#      54     "#!pip install --upgrade tensorflow"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": 2,
#      60    "metadata": {},
#      61    "outputs": [],
#      62    "source": [
#      63     "initial_learning_rate = 3e-4 #3e-4\n",
#      64     "lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\n",
#      65     "    initial_learning_rate,\n",
#      66     "    decay_steps=5000,\n",
#      67     "    decay_rate=0.96,\n",
#      68     "    staircase=True)"
#      69    ]
#      70   },
#      71   {
#      72    "cell_type": "code",
#      73    "execution_count": 3,
#      74    "metadata": {},
#      75    "outputs": [],
#      76    "source": [
#      77     "class CriticNetwork(keras.Model):\n",
#      78     "    def __init__(self, n_actions, fc1_dims=16, fc2_dims=16,  name='critic16', chkpt_dir='tmp16/sac16'):\n",
#      79     "        super(CriticNetwork, self).__init__()\n",
#      80     "        self.fc1_dims = fc1_dims\n",
#      81     "        self.fc2_dims = fc2_dims\n",
#      82     "        self.n_actions = n_actions\n",
#      83     "        self.model_name = name\n",
#      84     "        self.checkpoint_dir = chkpt_dir\n",
#      85     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#      86     "        \n",
#      87     "        #self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#      88     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#      89     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#      90     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=False)\n",
#      91     "        self.q = Dense(1, activation=None)\n",
#      92     "    def call(self, state, action):\n",
#      93     "        action_value = self.fc1(tf.concat([state, action], axis=-1))#two different ones\n",
#      94     "        action_value = self.fc2(action_value)\n",
#      95     "        #action_value = self.fc3(action_value)\n",
#      96     "        #action_value = self.fc4(action_value)\n",
#      97     "        \n",
#      98     "        q = self.q(action_value)\n",
#      99     "        \n",
#     100     "        return q\n",
#     101     "    \n",
#     102     "\n",
#     103     "class ValueNetwork(keras.Model):\n",
#     104     "    def __init__(self, n_actions, fc1_dims=16, fc2_dims=16,  name='value16', chkpt_dir='tmp16/sac16'):\n",
#     105     "        super(ValueNetwork, self).__init__()\n",
#     106     "        self.fc1_dims = fc1_dims\n",
#     107     "        self.fc2_dims = fc2_dims\n",
#     108     "        self.n_actions = n_actions\n",
#     109     "        self.model_name = name\n",
#     110     "        self.checkpoint_dir = chkpt_dir\n",
#     111     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#     112     "        \n",
#     113     "        #self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#     114     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#     115     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     116     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=False)\n",
#     117     "        self.v = Dense(1, activation=None)\n",
#     118     "    def call(self, state):\n",
#     119     "        state_value = self.fc1(state)\n",
#     120     "        state_value = self.fc2(state_value)\n",
#     121     "        #state_value = self.fc3(state_value)\n",
#     122     "        #state_value = self.fc4(state_value)\n",
#     123     "        \n",
#     124     "        v = self.v(state_value)\n",
#     125     "        \n",
#     126     "        return v\n",
#     127     "\n",
#     128     "class ActorNetwork(keras.Model):\n",
#     129     "    def __init__(self, max_action, fc1_dims=16, fc2_dims=16, n_actions = 1,  name='actor16', chkpt_dir='tmp16/sac16'):\n",
#     130     "        super(ActorNetwork, self).__init__()\n",
#     131     "        self.fc1_dims = fc1_dims\n",
#     132     "        self.fc2_dims = fc2_dims\n",
#     133     "        self.n_actions = n_actions\n",
#     134     "        self.max_action = max_action\n",
#     135     "        self.model_name = name\n",
#     136     "        self.checkpoint_dir = chkpt_dir\n",
#     137     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#     138     "        self.noise = 1e-6\n",
#     139     "        \n",
#     140     "       # self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#     141     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#     142     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     143     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     144     "        \n",
#     145     "        self.mu =  Dense(self.n_actions, activation=None)\n",
#     146     "        self.sigma = Dense(self.n_actions, activation=None)\n",
#     147     "    def call(self, state):\n",
#     148     "        prob = self.fc1(state)\n",
#     149     "        prob = self.fc2(prob)\n",
#     150     "\n",
#     151     "       # prob = self.fc3(prob)\n",
#     152     "        #prob = self.fc4(prob)\n",
#     153     "        \n",
#     154     "        \n",
#     155     "        mu = self.mu(prob)\n",
#     156     "        sigma = self.sigma(prob)\n",
#     157     "\n",
#     158     "        sigma = tf.clip_by_value(sigma, self.noise, 1)\n",
#     159     "        \n",
#     160     "        return mu, sigma\n",
#     161     "    def sample_normal(self, state):\n",
#     162     "        mu, sigma = self.call(state)\n",
#     163     "        #print(mu)\n",
#     164     "        #print(sigma)\n",
#     165     "        \n",
#     166     "        probabilities = tfp.distributions.Normal(mu, sigma)\n",
#     167     "        #print(probabilities)\n",
#     168     "        actions =  probabilities.sample()\n",
#     169     "        #print(actions)\n",
#     170     "     \n",
#     171     "        action = tf.math.tanh(actions)*self.max_action\n",
#     172     "        #print(action)\n",
#     173     "        \n",
#     174     "    \n",
#     175     "        \n",
#     176     "        log_probs = probabilities.log_prob(actions)\n",
#     177     "       # print(log_probs)\n",
#     178     "        \n",
#     179     "        log_probs = log_probs - tf.math.log(1-tf.math.pow(action, 2)+self.noise)\n",
#     180     "        #print(log_probs)\n",
#     181     "        log_probs = tf.math.reduce_sum(log_probs, axis=1, keepdims=True)\n",
#     182     "      \n",
#     183     "        \n",
#     184     "        return action, log_probs\n",
#     185     "        "
# --> 186    ]
#     187   },
#     188   {
#     189    "cell_type": "code",
#     190    "execution_count": 4,
#     191    "metadata": {},
#     192    "outputs": [],
#     193    "source": [
#     194     "class Agent16:\n",
#     195     "    def __init__(self, alpha=lr_schedule, beta=lr_schedule, input_dims=[8], env=None,\n",
#     196     "                gamma=0.99, n_actions=1, max_size=1000000, tau=0.005, layer1_size=16 #tau =0.005\n",
#     197     "                , layer2_size = 16, batch_size=256, reward_scale =2):\n",
#     198     "        self.gamma = gamma\n",
#     199     "        self.tau = tau\n",
#     200     "        self.memory = Experience_Replay.EP(max_size)\n",
#     201     "        self.batch_size = batch_size\n",
#     202     "        self.n_actions = n_actions\n",
#     203     "        \n",
#     204     "        self.actor= ActorNetwork(n_actions=n_actions,\n",
#     205     "                                max_action=1)\n",
#     206     "        self.critic_1 = CriticNetwork(n_actions=n_actions)\n",
#     207     "        self.critic_2 = CriticNetwork(n_actions=n_actions)\n",
#     208     "        self.value = ValueNetwork(n_actions=n_actions)\n",
#     209     "        self.target_value = ValueNetwork(n_actions=n_actions)\n",
#     210     "        \n",
#     211     "        self.actor.compile(optimizer=Adam(learning_rate=alpha))\n",
#     212     "        self.critic_1.compile(optimizer=Adam(learning_rate= beta))\n",
#     213     "        self.critic_2.compile(optimizer=Adam(learning_rate= beta))\n",
#     214     "        self.value.compile(optimizer=Adam(learning_rate= beta))\n",
#     215     "        self.target_value.compile(optimizer=Adam(learning_rate= beta))\n",
#     216     "        \n",
#     217     "        self.scale = reward_scale\n",
#     218     "        self.update_network_parameters(tau=1)\n",
#     219     "    def choose_action(self, observation, epi_time, start):\n",
#     220     "        if start == True:\n",
#     221     "            #print(observation[0])\n",
#     222     "            #print(observation[1])\n",
#     223     "            s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12 = observation[1]\n",
#     224     "            s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_ = observation[0]\n",
#     225     "           \n",
#     226     "            observation = np.array([s1[0], s2[0],s3[0]/1000,s4[0],s5[0],s6[0]/1000,s7,s8,s9,s10[0]/1000,s11[0],s12[0]])\n",
#     227     "            observation_1 = np.array([s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_])\n",
#     228     "        else:\n",
#     229     "            s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12 = observation[0]\n",
#     230     "            s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_ = observation[1]\n",
#     231     "          \n",
#     232     "            observation = np.array([s1[epi_time], s2[epi_time],s3[epi_time]/1000,s4[epi_time],s5[epi_time],s6[epi_time]/1000,s7,s8,s9,s10[epi_time]/1000,s11[epi_time],s12[epi_time]])\n",
#     233     "            observation_1 = np.array([s1_[epi_time], s2_[epi_time],s3_[epi_time]/1000,s4_[epi_time],s5_[epi_time],s6_[epi_time]/1000,s7_,s8_,s9_,s10_[epi_time]/1000,s11_[epi_time],s12_[epi_time]])\n",
#     234     "        \n",
#     235     "        observation = np.concatenate([observation,observation_1]) \n",
#     236     "        observation = np.expand_dims(observation, axis=0)#observation.reshape(2,12)\n",
#     237     "        state = tf.convert_to_tensor([observation])\n",
#     238     "        \n",
#     239     "        actions,l = self.actor.sample_normal(state)\n",
#     240     "        return actions[0]\n",
#     241     "    def remember(self, state, action, reward, new_state, done):\n",
#     242     "        #self.memory.update(state, action, reward, new_state, done)\n",
#     243     "        self.exp_1 = self.memory.update(state, action, reward, new_state, done)\n",
#     244     "        self.done = done\n",
#     245     "    def update_network_parameters(self, tau=None):\n",
#     246     "        if tau is None:\n",
#     247     "            tau= self.tau\n",
#     248     "        weights = []\n",
#     249     "        targets = self.target_value.weights\n",
#     250     "        for i, weight in enumerate(self.target_value.weights):\n",
#     251     "            weights.append(weight*tau + targets[i]*(1-tau))\n",
#     252     "        self.target_value.set_weights(weights)\n",
#     253     "        \n",
#     254     "    def save_models(self):\n",
#     255     "        print('... saving models ...')\n",
#     256     "        self.actor.save_weights(self.actor.checkpoint_file)\n",
#     257     "        self.critic_1.save_weights(self.critic_1.checkpoint_file)\n",
#     258     "        self.critic_2.save_weights(self.critic_2.checkpoint_file)\n",
#     259     "        self.value.save_weights(self.value.checkpoint_file)\n",
#     260     "        self.target_value.save_weights(self.target_value.checkpoint_file)\n",
#     261     "\n",
#     262     "    def load_models(self):\n",
#     263     "        print('... loading models ...')\n",
#     264     "        self.actor.load_weights(self.actor.checkpoint_file)\n",
#     265     "        self.critic_1.load_weights(self.critic_1.checkpoint_file)\n",
#     266     "        self.critic_2.load_weights(self.critic_2.checkpoint_file)\n",
#     267     "        self.value.load_weights(self.value.checkpoint_file)\n",
#     268     "        self.target_value.load_weights(self.target_value.checkpoint_file)\n",
#     269     "\n",
#     270     "    \n",
#     271     "    def learn(self):\n",
#     272     "        exp_length = len(self.exp_1)\n",
#     273     "        if exp_length < self.batch_size:\n",
#     274     "            return\n",
#     275     "        #print('Learning.......')\n",
#     276     "        self.batch_train = self.memory.sample(self.batch_size)\n",
#     277     "        state = []\n",
#     278     "        action = []\n",
#     279     "        reward = []\n",
#     280     "        new_state = []\n",
#     281     "        done = []\n",
#     282     "        for i in range(len(self.batch_train)):\n",
#     283     "            state.append(self.batch_train[i][0])\n",
#     284     "            action.append(self.batch_train[i][1])\n",
#     285     "            reward.append(self.batch_train[i][2])\n",
#     286     "            new_state.append(self.batch_train[i][3])\n",
#     287     "            done.append(self.batch_train[i][4])\n",
#     288     "        \n",
#     289     "        \n",
#     290     "        state =np.asarray(state, dtype=np.float32)\n",
#     291     "        #print(state.shape)\n",
#     292     "        state =np.asarray(np.expand_dims(state, axis=0), dtype=np.float32) #state.reshape(state[0],) np.expand_dims(x, axis=0)\n",
#     293     "        action =np.asarray(action, dtype=np.float32)\n",
#     294     "        action =np.asarray(np.expand_dims(action, axis=0), dtype=np.float32) #action.reshape(256,2,None)\n",
#     295     "        reward = np.asarray(reward, dtype=np.float32)\n",
#     296     "        reward = np.asarray(np.expand_dims(reward, axis=0), dtype=np.float32)#reward.reshape(256,2,None)\n",
#     297     "        new_state =np.asarray(new_state, dtype=np.float32)\n",
#     298     "        new_state = np.asarray(np.expand_dims(new_state, axis=0), dtype=np.float32)#new_state.reshape(256,2,None)\n",
#     299     "        done =np.asarray(done, dtype=np.float32)\n",
#     300     "        \n",
#     301     "        \n",
#     302     "        \n",
#     303     "            \n",
#     304     "        states = tf.convert_to_tensor(state, dtype=tf.float32)\n",
#     305     "        states_ = tf.convert_to_tensor(new_state, dtype=tf.float32)\n",
#     306     "        rewards = tf.convert_to_tensor(reward, dtype=tf.float32)\n",
#     307     "        actions = tf.convert_to_tensor(action, dtype=tf.float32)\n",
#     308     "        \n",
#     309     "        with tf.GradientTape() as tape:\n",
#     310     "            value = tf.squeeze(self.value(states), 0)#if it is not 1,256,24 it should be axis 1 but in this case it's zero since thats where the 1 is\n",
#     311     "           \n",
#     312     "            value_ = tf.squeeze(self.target_value(states_), 0)\n",
#     313     "            \n",
#     314     "            current_policy_actions, log_probs = self.actor.sample_normal(states)\n",
#     315     "            print(current_policy_actions.shape)\n",
#     316     "            log_probs = tf.squeeze(log_probs, 0)\n",
#     317     "            q1_new_policy = self.critic_1(states, current_policy_actions)\n",
#     318     "            q2_new_policy = self.critic_1(states, current_policy_actions)\n",
#     319     "            critic_value = tf.squeeze(tf.math.minimum(q1_new_policy, q2_new_policy), 0)\n",
#     320     "            value_target = critic_value-(log_probs)\n",
#     321     "            value_loss = 0.5* keras.losses.MSE(value, value_target)\n",
#     322     "            \n",
#     323     "        value_network_gradient = tape.gradient(value_loss, self.value.trainable_variables)\n",
#     324     "            \n",
#     325     "        self.value.optimizer.apply_gradients(zip(value_network_gradient, self.value.trainable_variables ))\n",
#     326     "    \n",
#     327     "        with tf.GradientTape() as tape:\n",
#     328     "\n",
#     329     "            new_policy_actions, log_probs = self.actor.sample_normal(states)\n",
#     330     "            #print(f'2 {new_policy_actions.shape}')\n",
#     331     "            log_probs = tf.squeeze(log_probs, 0)\n",
#     332     "            q1_new_policy = self.critic_1(states, new_policy_actions)\n",
#     333     "            q2_new_policy = self.critic_1(states, new_policy_actions)  \n",
#     334     "            \n",
#     335     "            critic_value = tf.squeeze(tf.math.minimum(q1_new_policy, q2_new_policy), 0)\n",
#     336     "            \n",
#     337     "            actor_loss = (log_probs) - critic_value\n",
#     338     "            actor_loss = tf.math.reduce_mean(actor_loss)\n",
#     339     "            print(actor_loss)\n",
#     340     "            \n",
#     341     "        actor_network_gradient =  tape.gradient(actor_loss, self.actor.trainable_variables)\n",
#     342     "        \n",
#     343     "        self.actor.optimizer.apply_gradients(zip(actor_network_gradient, self.actor.trainable_variables ))\n",
#     344     "        \n",
#     345     "        with tf.GradientTape(persistent=True) as tape:\n",
#     346     "            \n",
#     347     "            q_hat = self.scale*rewards + self.gamma*value_*(1-int(0)) #entropy term\n",
#     348     "            action = np.squeeze(action, axis=3)\n",
#     349     "            #action = action[0]\n",
#     350     "            #action = np.delete(action, 1, 1)\n",
#     351     "            #action = np.asarray(np.expand_dims(action, axis=0), dtype=np.float32)\n",
#     352     "            q1_old_policy = tf.squeeze(self.critic_1(state, action), 0)\n",
#     353     "            q2_old_policy = tf.squeeze(self.critic_2(state, action), 0)\n",
#     354     "           \n",
#     355     "            critic_1_loss = 0.5*keras.losses.MSE(q1_old_policy, q_hat)\n",
#     356     "            critic_2_loss =  0.5*keras.losses.MSE(q2_old_policy, q_hat)\n",
#     357     "          \n",
#     358     "        critic_1_network_gradient = tape.gradient(critic_1_loss, self.critic_1.trainable_variables)\n",
#     359     "        critic_2_network_gradient = tape.gradient(critic_2_loss, self.critic_2.trainable_variables)\n",
#     360     "            \n",
#     361     "        self.critic_1.optimizer.apply_gradients(zip(critic_1_network_gradient, self.critic_1.trainable_variables))\n",
#     362     "        self.critic_2.optimizer.apply_gradients(zip(critic_2_network_gradient, self.critic_2.trainable_variables))\n",
#     363     "        \n",
#     364     "        self.update_network_parameters()\n",
#     365     "                \n",
#     366     "            \n",
#     367     "            "
#     368    ]
#     369   },
#     370   {
#     371    "cell_type": "code",
#     372    "execution_count": 7,
#     373    "metadata": {},
#     374    "outputs": [],
#     375    "source": [
#     376     "#constraint network, feed state and action and the push out constraint violation then loss is mse(with actual violation)\n",
#     377     "#create experience buffer for the constraint network to train on can start learning after 1000 time steps\n",
#     378     "#from this give out the constraint network\n",
#     379     "#give out the constraint to another network"
#     380    ]
#     381   },
#     382   {
#     383    "cell_type": "code",
#     384    "execution_count": null,
#     385    "metadata": {},
#     386    "outputs": [],
#     387    "source": []
#     388   }
#     389  ],
#     390  "metadata": {
#     391   "kernelspec": {
#     392    "display_name": "Python 3 (ipykernel)",
#     393    "language": "python",
#     394    "name": "python3"
#     395   },
#     396   "language_info": {
#     397    "codemirror_mode": {
#     398     "name": "ipython",
#     399     "version": 3
#     400    },
#     401    "file_extension": ".py",
#     402    "mimetype": "text/x-python",
#     403    "name": "python",
#     404    "nbconvert_exporter": "python",
#     405    "pygments_lexer": "ipython3",
#     406    "version": "3.9.13"
#     407   }
#     408  },
#     409  "nbformat": 4,
#     410  "nbformat_minor": 4
#     411 }
#
# File ~\Downloads\RL\S_A_C_16.ipynb:122, in sample_normal(self, state)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [
#       8     {
#       9      "name": "stdout",
#      10      "output_type": "stream",
#      11      "text": [
#      12       "importing Jupyter notebook from Experience_Replay.ipynb\n"
#      13      ]
#      14     }
#      15    ],
#      16    "source": [
#      17     "import os\n",
#      18     "import numpy as np\n",
#      19     "import tensorflow as tf\n",
#      20     "import tensorflow.keras as keras\n",
#      21     "import tensorflow_probability as tfp\n",
#      22     "from tensorflow.keras.layers import Dense, LeakyReLU, LSTM\n",
#      23     "import import_ipynb\n",
#      24     "import Experience_Replay\n",
#      25     "from tensorflow.keras.optimizers import Adam\n",
#      26     "from tensorflow.keras.optimizers.schedules import ExponentialDecay"
#      27    ]
#      28   },
#      29   {
#      30    "cell_type": "code",
#      31    "execution_count": 2,
#      32    "metadata": {},
#      33    "outputs": [],
#      34    "source": [
#      35     "#!pip install --upgrade tensorflow"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": 3,
#      41    "metadata": {},
#      42    "outputs": [],
#      43    "source": [
#      44     "#import tensorflow as tf\n",
#      45     "#tf.version.VERSION"
#      46    ]
#      47   },
#      48   {
#      49    "cell_type": "code",
#      50    "execution_count": 4,
#      51    "metadata": {},
#      52    "outputs": [],
#      53    "source": [
#      54     "#!pip install --upgrade tensorflow"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": 2,
#      60    "metadata": {},
#      61    "outputs": [],
#      62    "source": [
#      63     "initial_learning_rate = 3e-4 #3e-4\n",
#      64     "lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\n",
#      65     "    initial_learning_rate,\n",
#      66     "    decay_steps=5000,\n",
#      67     "    decay_rate=0.96,\n",
#      68     "    staircase=True)"
#      69    ]
#      70   },
#      71   {
#      72    "cell_type": "code",
#      73    "execution_count": 3,
#      74    "metadata": {},
#      75    "outputs": [],
#      76    "source": [
#      77     "class CriticNetwork(keras.Model):\n",
#      78     "    def __init__(self, n_actions, fc1_dims=16, fc2_dims=16,  name='critic16', chkpt_dir='tmp16/sac16'):\n",
#      79     "        super(CriticNetwork, self).__init__()\n",
#      80     "        self.fc1_dims = fc1_dims\n",
#      81     "        self.fc2_dims = fc2_dims\n",
#      82     "        self.n_actions = n_actions\n",
#      83     "        self.model_name = name\n",
#      84     "        self.checkpoint_dir = chkpt_dir\n",
#      85     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#      86     "        \n",
#      87     "        #self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#      88     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#      89     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#      90     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=False)\n",
#      91     "        self.q = Dense(1, activation=None)\n",
#      92     "    def call(self, state, action):\n",
#      93     "        action_value = self.fc1(tf.concat([state, action], axis=-1))#two different ones\n",
#      94     "        action_value = self.fc2(action_value)\n",
#      95     "        #action_value = self.fc3(action_value)\n",
#      96     "        #action_value = self.fc4(action_value)\n",
#      97     "        \n",
#      98     "        q = self.q(action_value)\n",
#      99     "        \n",
#     100     "        return q\n",
#     101     "    \n",
#     102     "\n",
#     103     "class ValueNetwork(keras.Model):\n",
#     104     "    def __init__(self, n_actions, fc1_dims=16, fc2_dims=16,  name='value16', chkpt_dir='tmp16/sac16'):\n",
#     105     "        super(ValueNetwork, self).__init__()\n",
#     106     "        self.fc1_dims = fc1_dims\n",
#     107     "        self.fc2_dims = fc2_dims\n",
#     108     "        self.n_actions = n_actions\n",
#     109     "        self.model_name = name\n",
#     110     "        self.checkpoint_dir = chkpt_dir\n",
#     111     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#     112     "        \n",
#     113     "        #self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#     114     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#     115     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     116     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=False)\n",
#     117     "        self.v = Dense(1, activation=None)\n",
#     118     "    def call(self, state):\n",
#     119     "        state_value = self.fc1(state)\n",
#     120     "        state_value = self.fc2(state_value)\n",
#     121     "        #state_value = self.fc3(state_value)\n",
# --> 122     "        #state_value = self.fc4(state_value)\n",
#     123     "        \n",
#     124     "        v = self.v(state_value)\n",
#     125     "        \n",
#     126     "        return v\n",
#     127     "\n",
#     128     "class ActorNetwork(keras.Model):\n",
#     129     "    def __init__(self, max_action, fc1_dims=16, fc2_dims=16, n_actions = 1,  name='actor16', chkpt_dir='tmp16/sac16'):\n",
#     130     "        super(ActorNetwork, self).__init__()\n",
#     131     "        self.fc1_dims = fc1_dims\n",
#     132     "        self.fc2_dims = fc2_dims\n",
#     133     "        self.n_actions = n_actions\n",
#     134     "        self.max_action = max_action\n",
#     135     "        self.model_name = name\n",
#     136     "        self.checkpoint_dir = chkpt_dir\n",
#     137     "        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_sac16')\n",
#     138     "        self.noise = 1e-6\n",
#     139     "        \n",
#     140     "       # self.fc1 = Dense(self.fc1_dims, activation=LeakyReLU())\n",
#     141     "        #self.fc2 = Dense(self.fc2_dims, activation=LeakyReLU())\n",
#     142     "        self.fc1 = LSTM(self.fc1_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     143     "        self.fc2 = LSTM(self.fc2_dims, activation=LeakyReLU(), return_sequences=True)\n",
#     144     "        \n",
#     145     "        self.mu =  Dense(self.n_actions, activation=None)\n",
#     146     "        self.sigma = Dense(self.n_actions, activation=None)\n",
#     147     "    def call(self, state):\n",
#     148     "        prob = self.fc1(state)\n",
#     149     "        prob = self.fc2(prob)\n",
#     150     "\n",
#     151     "       # prob = self.fc3(prob)\n",
#     152     "        #prob = self.fc4(prob)\n",
#     153     "        \n",
#     154     "        \n",
#     155     "        mu = self.mu(prob)\n",
#     156     "        sigma = self.sigma(prob)\n",
#     157     "\n",
#     158     "        sigma = tf.clip_by_value(sigma, self.noise, 1)\n",
#     159     "        \n",
#     160     "        return mu, sigma\n",
#     161     "    def sample_normal(self, state):\n",
#     162     "        mu, sigma = self.call(state)\n",
#     163     "        #print(mu)\n",
#     164     "        #print(sigma)\n",
#     165     "        \n",
#     166     "        probabilities = tfp.distributions.Normal(mu, sigma)\n",
#     167     "        #print(probabilities)\n",
#     168     "        actions =  probabilities.sample()\n",
#     169     "        #print(actions)\n",
#     170     "     \n",
#     171     "        action = tf.math.tanh(actions)*self.max_action\n",
#     172     "        #print(action)\n",
#     173     "        \n",
#     174     "    \n",
#     175     "        \n",
#     176     "        log_probs = probabilities.log_prob(actions)\n",
#     177     "       # print(log_probs)\n",
#     178     "        \n",
#     179     "        log_probs = log_probs - tf.math.log(1-tf.math.pow(action, 2)+self.noise)\n",
#     180     "        #print(log_probs)\n",
#     181     "        log_probs = tf.math.reduce_sum(log_probs, axis=1, keepdims=True)\n",
#     182     "      \n",
#     183     "        \n",
#     184     "        return action, log_probs\n",
#     185     "        "
#     186    ]
#     187   },
#     188   {
#     189    "cell_type": "code",
#     190    "execution_count": 4,
#     191    "metadata": {},
#     192    "outputs": [],
#     193    "source": [
#     194     "class Agent16:\n",
#     195     "    def __init__(self, alpha=lr_schedule, beta=lr_schedule, input_dims=[8], env=None,\n",
#     196     "                gamma=0.99, n_actions=1, max_size=1000000, tau=0.005, layer1_size=16 #tau =0.005\n",
#     197     "                , layer2_size = 16, batch_size=256, reward_scale =2):\n",
#     198     "        self.gamma = gamma\n",
#     199     "        self.tau = tau\n",
#     200     "        self.memory = Experience_Replay.EP(max_size)\n",
#     201     "        self.batch_size = batch_size\n",
#     202     "        self.n_actions = n_actions\n",
#     203     "        \n",
#     204     "        self.actor= ActorNetwork(n_actions=n_actions,\n",
#     205     "                                max_action=1)\n",
#     206     "        self.critic_1 = CriticNetwork(n_actions=n_actions)\n",
#     207     "        self.critic_2 = CriticNetwork(n_actions=n_actions)\n",
#     208     "        self.value = ValueNetwork(n_actions=n_actions)\n",
#     209     "        self.target_value = ValueNetwork(n_actions=n_actions)\n",
#     210     "        \n",
#     211     "        self.actor.compile(optimizer=Adam(learning_rate=alpha))\n",
#     212     "        self.critic_1.compile(optimizer=Adam(learning_rate= beta))\n",
#     213     "        self.critic_2.compile(optimizer=Adam(learning_rate= beta))\n",
#     214     "        self.value.compile(optimizer=Adam(learning_rate= beta))\n",
#     215     "        self.target_value.compile(optimizer=Adam(learning_rate= beta))\n",
#     216     "        \n",
#     217     "        self.scale = reward_scale\n",
#     218     "        self.update_network_parameters(tau=1)\n",
#     219     "    def choose_action(self, observation, epi_time, start):\n",
#     220     "        if start == True:\n",
#     221     "            #print(observation[0])\n",
#     222     "            #print(observation[1])\n",
#     223     "            s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12 = observation[1]\n",
#     224     "            s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_ = observation[0]\n",
#     225     "           \n",
#     226     "            observation = np.array([s1[0], s2[0],s3[0]/1000,s4[0],s5[0],s6[0]/1000,s7,s8,s9,s10[0]/1000,s11[0],s12[0]])\n",
#     227     "            observation_1 = np.array([s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_])\n",
#     228     "        else:\n",
#     229     "            s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12 = observation[0]\n",
#     230     "            s1_,s2_,s3_,s4_,s5_,s6_,s7_,s8_,s9_,s10_,s11_,s12_ = observation[1]\n",
#     231     "          \n",
#     232     "            observation = np.array([s1[epi_time], s2[epi_time],s3[epi_time]/1000,s4[epi_time],s5[epi_time],s6[epi_time]/1000,s7,s8,s9,s10[epi_time]/1000,s11[epi_time],s12[epi_time]])\n",
#     233     "            observation_1 = np.array([s1_[epi_time], s2_[epi_time],s3_[epi_time]/1000,s4_[epi_time],s5_[epi_time],s6_[epi_time]/1000,s7_,s8_,s9_,s10_[epi_time]/1000,s11_[epi_time],s12_[epi_time]])\n",
#     234     "        \n",
#     235     "        observation = np.concatenate([observation,observation_1]) \n",
#     236     "        observation = np.expand_dims(observation, axis=0)#observation.reshape(2,12)\n",
#     237     "        state = tf.convert_to_tensor([observation])\n",
#     238     "        \n",
#     239     "        actions,l = self.actor.sample_normal(state)\n",
#     240     "        return actions[0]\n",
#     241     "    def remember(self, state, action, reward, new_state, done):\n",
#     242     "        #self.memory.update(state, action, reward, new_state, done)\n",
#     243     "        self.exp_1 = self.memory.update(state, action, reward, new_state, done)\n",
#     244     "        self.done = done\n",
#     245     "    def update_network_parameters(self, tau=None):\n",
#     246     "        if tau is None:\n",
#     247     "            tau= self.tau\n",
#     248     "        weights = []\n",
#     249     "        targets = self.target_value.weights\n",
#     250     "        for i, weight in enumerate(self.target_value.weights):\n",
#     251     "            weights.append(weight*tau + targets[i]*(1-tau))\n",
#     252     "        self.target_value.set_weights(weights)\n",
#     253     "        \n",
#     254     "    def save_models(self):\n",
#     255     "        print('... saving models ...')\n",
#     256     "        self.actor.save_weights(self.actor.checkpoint_file)\n",
#     257     "        self.critic_1.save_weights(self.critic_1.checkpoint_file)\n",
#     258     "        self.critic_2.save_weights(self.critic_2.checkpoint_file)\n",
#     259     "        self.value.save_weights(self.value.checkpoint_file)\n",
#     260     "        self.target_value.save_weights(self.target_value.checkpoint_file)\n",
#     261     "\n",
#     262     "    def load_models(self):\n",
#     263     "        print('... loading models ...')\n",
#     264     "        self.actor.load_weights(self.actor.checkpoint_file)\n",
#     265     "        self.critic_1.load_weights(self.critic_1.checkpoint_file)\n",
#     266     "        self.critic_2.load_weights(self.critic_2.checkpoint_file)\n",
#     267     "        self.value.load_weights(self.value.checkpoint_file)\n",
#     268     "        self.target_value.load_weights(self.target_value.checkpoint_file)\n",
#     269     "\n",
#     270     "    \n",
#     271     "    def learn(self):\n",
#     272     "        exp_length = len(self.exp_1)\n",
#     273     "        if exp_length < self.batch_size:\n",
#     274     "            return\n",
#     275     "        #print('Learning.......')\n",
#     276     "        self.batch_train = self.memory.sample(self.batch_size)\n",
#     277     "        state = []\n",
#     278     "        action = []\n",
#     279     "        reward = []\n",
#     280     "        new_state = []\n",
#     281     "        done = []\n",
#     282     "        for i in range(len(self.batch_train)):\n",
#     283     "            state.append(self.batch_train[i][0])\n",
#     284     "            action.append(self.batch_train[i][1])\n",
#     285     "            reward.append(self.batch_train[i][2])\n",
#     286     "            new_state.append(self.batch_train[i][3])\n",
#     287     "            done.append(self.batch_train[i][4])\n",
#     288     "        \n",
#     289     "        \n",
#     290     "        state =np.asarray(state, dtype=np.float32)\n",
#     291     "        #print(state.shape)\n",
#     292     "        state =np.asarray(np.expand_dims(state, axis=0), dtype=np.float32) #state.reshape(state[0],) np.expand_dims(x, axis=0)\n",
#     293     "        action =np.asarray(action, dtype=np.float32)\n",
#     294     "        action =np.asarray(np.expand_dims(action, axis=0), dtype=np.float32) #action.reshape(256,2,None)\n",
#     295     "        reward = np.asarray(reward, dtype=np.float32)\n",
#     296     "        reward = np.asarray(np.expand_dims(reward, axis=0), dtype=np.float32)#reward.reshape(256,2,None)\n",
#     297     "        new_state =np.asarray(new_state, dtype=np.float32)\n",
#     298     "        new_state = np.asarray(np.expand_dims(new_state, axis=0), dtype=np.float32)#new_state.reshape(256,2,None)\n",
#     299     "        done =np.asarray(done, dtype=np.float32)\n",
#     300     "        \n",
#     301     "        \n",
#     302     "        \n",
#     303     "            \n",
#     304     "        states = tf.convert_to_tensor(state, dtype=tf.float32)\n",
#     305     "        states_ = tf.convert_to_tensor(new_state, dtype=tf.float32)\n",
#     306     "        rewards = tf.convert_to_tensor(reward, dtype=tf.float32)\n",
#     307     "        actions = tf.convert_to_tensor(action, dtype=tf.float32)\n",
#     308     "        \n",
#     309     "        with tf.GradientTape() as tape:\n",
#     310     "            value = tf.squeeze(self.value(states), 0)#if it is not 1,256,24 it should be axis 1 but in this case it's zero since thats where the 1 is\n",
#     311     "           \n",
#     312     "            value_ = tf.squeeze(self.target_value(states_), 0)\n",
#     313     "            \n",
#     314     "            current_policy_actions, log_probs = self.actor.sample_normal(states)\n",
#     315     "            print(current_policy_actions.shape)\n",
#     316     "            log_probs = tf.squeeze(log_probs, 0)\n",
#     317     "            q1_new_policy = self.critic_1(states, current_policy_actions)\n",
#     318     "            q2_new_policy = self.critic_1(states, current_policy_actions)\n",
#     319     "            critic_value = tf.squeeze(tf.math.minimum(q1_new_policy, q2_new_policy), 0)\n",
#     320     "            value_target = critic_value-(log_probs)\n",
#     321     "            value_loss = 0.5* keras.losses.MSE(value, value_target)\n",
#     322     "            \n",
#     323     "        value_network_gradient = tape.gradient(value_loss, self.value.trainable_variables)\n",
#     324     "            \n",
#     325     "        self.value.optimizer.apply_gradients(zip(value_network_gradient, self.value.trainable_variables ))\n",
#     326     "    \n",
#     327     "        with tf.GradientTape() as tape:\n",
#     328     "\n",
#     329     "            new_policy_actions, log_probs = self.actor.sample_normal(states)\n",
#     330     "            #print(f'2 {new_policy_actions.shape}')\n",
#     331     "            log_probs = tf.squeeze(log_probs, 0)\n",
#     332     "            q1_new_policy = self.critic_1(states, new_policy_actions)\n",
#     333     "            q2_new_policy = self.critic_1(states, new_policy_actions)  \n",
#     334     "            \n",
#     335     "            critic_value = tf.squeeze(tf.math.minimum(q1_new_policy, q2_new_policy), 0)\n",
#     336     "            \n",
#     337     "            actor_loss = (log_probs) - critic_value\n",
#     338     "            actor_loss = tf.math.reduce_mean(actor_loss)\n",
#     339     "            print(actor_loss)\n",
#     340     "            \n",
#     341     "        actor_network_gradient =  tape.gradient(actor_loss, self.actor.trainable_variables)\n",
#     342     "        \n",
#     343     "        self.actor.optimizer.apply_gradients(zip(actor_network_gradient, self.actor.trainable_variables ))\n",
#     344     "        \n",
#     345     "        with tf.GradientTape(persistent=True) as tape:\n",
#     346     "            \n",
#     347     "            q_hat = self.scale*rewards + self.gamma*value_*(1-int(0)) #entropy term\n",
#     348     "            action = np.squeeze(action, axis=3)\n",
#     349     "            #action = action[0]\n",
#     350     "            #action = np.delete(action, 1, 1)\n",
#     351     "            #action = np.asarray(np.expand_dims(action, axis=0), dtype=np.float32)\n",
#     352     "            q1_old_policy = tf.squeeze(self.critic_1(state, action), 0)\n",
#     353     "            q2_old_policy = tf.squeeze(self.critic_2(state, action), 0)\n",
#     354     "           \n",
#     355     "            critic_1_loss = 0.5*keras.losses.MSE(q1_old_policy, q_hat)\n",
#     356     "            critic_2_loss =  0.5*keras.losses.MSE(q2_old_policy, q_hat)\n",
#     357     "          \n",
#     358     "        critic_1_network_gradient = tape.gradient(critic_1_loss, self.critic_1.trainable_variables)\n",
#     359     "        critic_2_network_gradient = tape.gradient(critic_2_loss, self.critic_2.trainable_variables)\n",
#     360     "            \n",
#     361     "        self.critic_1.optimizer.apply_gradients(zip(critic_1_network_gradient, self.critic_1.trainable_variables))\n",
#     362     "        self.critic_2.optimizer.apply_gradients(zip(critic_2_network_gradient, self.critic_2.trainable_variables))\n",
#     363     "        \n",
#     364     "        self.update_network_parameters()\n",
#     365     "                \n",
#     366     "            \n",
#     367     "            "
#     368    ]
#     369   },
#     370   {
#     371    "cell_type": "code",
#     372    "execution_count": 7,
#     373    "metadata": {},
#     374    "outputs": [],
#     375    "source": [
#     376     "#constraint network, feed state and action and the push out constraint violation then loss is mse(with actual violation)\n",
#     377     "#create experience buffer for the constraint network to train on can start learning after 1000 time steps\n",
#     378     "#from this give out the constraint network\n",
#     379     "#give out the constraint to another network"
#     380    ]
#     381   },
#     382   {
#     383    "cell_type": "code",
#     384    "execution_count": null,
#     385    "metadata": {},
#     386    "outputs": [],
#     387    "source": []
#     388   }
#     389  ],
#     390  "metadata": {
#     391   "kernelspec": {
#     392    "display_name": "Python 3 (ipykernel)",
#     393    "language": "python",
#     394    "name": "python3"
#     395   },
#     396   "language_info": {
#     397    "codemirror_mode": {
#     398     "name": "ipython",
#     399     "version": 3
#     400    },
#     401    "file_extension": ".py",
#     402    "mimetype": "text/x-python",
#     403    "name": "python",
#     404    "nbconvert_exporter": "python",
#     405    "pygments_lexer": "ipython3",
#     406    "version": "3.9.13"
#     407   }
#     408  },
#     409  "nbformat": 4,
#     410  "nbformat_minor": 4
#     411 }
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:1234, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1219 """Generate samples of the specified shape.
#    1220
#    1221 Note that a call to `sample()` without arguments will generate a single
#    (...)
#    1231   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1232 """
#    1233 with self._name_and_control_scope(name):
# -> 1234   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:1211, in Distribution._call_sample_n(self, sample_shape, seed, **kwargs)
#    1207 sample_shape = ps.convert_to_shape_tensor(
#    1208     ps.cast(sample_shape, tf.int32), name='sample_shape')
#    1209 sample_shape, n = self._expand_sample_shape_to_vector(
#    1210     sample_shape, 'sample_shape')
# -> 1211 samples = self._sample_n(
#    1212     n, seed=seed() if callable(seed) else seed, **kwargs)
#    1213 samples = tf.nest.map_structure(
#    1214     lambda x: tf.reshape(x, ps.concat([sample_shape, ps.shape(x)[1:]], 0)),
#    1215     samples)
#    1216 return self._set_sample_static_shape(samples, sample_shape)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\distributions\normal.py:177, in Normal._sample_n(self, n, seed)
#     175 loc = tf.convert_to_tensor(self.loc)
#     176 scale = tf.convert_to_tensor(self.scale)
# --> 177 shape = ps.concat([[n], self._batch_shape_tensor(loc=loc, scale=scale)],
#     178                   axis=0)
#     179 sampled = samplers.normal(
#     180     shape=shape, mean=0., stddev=1., dtype=self.dtype, seed=seed)
#     181 return sampled * scale + loc
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:1013, in Distribution._batch_shape_tensor(self, **parameter_kwargs)
#     986 """Infers batch shape from parameters.
#     987
#     988 The overall batch shape is inferred by broadcasting the batch shapes of
#    (...)
#    1010   batch_shape_tensor: `Tensor` broadcast batch shape of all parameters.
#    1011 """
#    1012 try:
# -> 1013   return batch_shape_lib.inferred_batch_shape_tensor(
#    1014       self, **parameter_kwargs)
#    1015 except NotImplementedError:
#    1016   raise NotImplementedError('Cannot compute batch shape of distribution '
#    1017                             '{}: you must implement at least one of '
#    1018                             '`_batch_shape_tensor` or '
#    1019                             '`_parameter_properties`.'.format(self))
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\internal\batch_shape_lib.py:110, in inferred_batch_shape_tensor(batch_object, bijector_x_event_ndims, **parameter_kwargs)
#      78 def inferred_batch_shape_tensor(batch_object,
#      79                                 bijector_x_event_ndims=None,
#      80                                 **parameter_kwargs):
#      81   """Infers an object's batch shape from its  parameters.
#      82
#      83   Each parameter contributes a batch shape of
#    (...)
#     108     batch_shape_tensor: `Tensor` broadcast batch shape of all parameters.
#     109   """
# --> 110   batch_shapes = map_fn_over_parameters_with_event_ndims(
#     111       batch_object,
#     112       get_batch_shape_tensor_part,
#     113       bijector_x_event_ndims=bijector_x_event_ndims,
#     114       require_static=False,
#     115       **parameter_kwargs)
#     116   return functools.reduce(ps.broadcast_shape, tf.nest.flatten(batch_shapes), [])
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\internal\batch_shape_lib.py:365, in map_fn_over_parameters_with_event_ndims(batch_object, fn, bijector_x_event_ndims, require_static, **parameter_kwargs)
#     359     elif (properties.is_tensor
#     360           and not tf.is_tensor(param)
#     361           and not tf.nest.is_nested(param_event_ndims)):
#     362       # As a last resort, try an explicit conversion.
#     363       param = tensor_util.convert_nonref_to_tensor(param, name=param_name)
# --> 365   results[param_name] = nest.map_structure_up_to(
#     366       param, fn, param, param_event_ndims)
#     367 return results
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\nest.py:1428, in map_structure_up_to(shallow_tree, func, *inputs, **kwargs)
#    1354 @tf_export("__internal__.nest.map_structure_up_to", v1=[])
#    1355 def map_structure_up_to(shallow_tree, func, *inputs, **kwargs):
#    1356   """Applies a function or op to a number of partially flattened inputs.
#    1357
#    1358   The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)
#    1426     `shallow_tree`.
#    1427   """
# -> 1428   return map_structure_with_tuple_paths_up_to(
#    1429       shallow_tree,
#    1430       lambda _, *values: func(*values),  # Discards the path arg.
#    1431       *inputs,
#    1432       **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\nest.py:1528, in map_structure_with_tuple_paths_up_to(shallow_tree, func, *inputs, **kwargs)
#    1519 flat_value_gen = (
#    1520     flatten_up_to(  # pylint: disable=g-complex-comprehension
#    1521         shallow_tree,
#    1522         input_tree,
#    1523         check_types,
#    1524         expand_composites=expand_composites) for input_tree in inputs)
#    1525 flat_path_gen = (
#    1526     path
#    1527     for path, _ in _yield_flat_up_to(shallow_tree, inputs[0], is_nested_fn))
# -> 1528 results = [
#    1529     func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1530 ]
#    1531 return pack_sequence_as(structure=shallow_tree, flat_sequence=results,
#    1532                         expand_composites=expand_composites)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\nest.py:1529, in <listcomp>(.0)
#    1519 flat_value_gen = (
#    1520     flatten_up_to(  # pylint: disable=g-complex-comprehension
#    1521         shallow_tree,
#    1522         input_tree,
#    1523         check_types,
#    1524         expand_composites=expand_composites) for input_tree in inputs)
#    1525 flat_path_gen = (
#    1526     path
#    1527     for path, _ in _yield_flat_up_to(shallow_tree, inputs[0], is_nested_fn))
#    1528 results = [
# -> 1529     func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1530 ]
#    1531 return pack_sequence_as(structure=shallow_tree, flat_sequence=results,
#    1532                         expand_composites=expand_composites)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\nest.py:1430, in map_structure_up_to.<locals>.<lambda>(_, *values)
#    1354 @tf_export("__internal__.nest.map_structure_up_to", v1=[])
#    1355 def map_structure_up_to(shallow_tree, func, *inputs, **kwargs):
#    1356   """Applies a function or op to a number of partially flattened inputs.
#    1357
#    1358   The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)
#    1426     `shallow_tree`.
#    1427   """
#    1428   return map_structure_with_tuple_paths_up_to(
#    1429       shallow_tree,
# -> 1430       lambda _, *values: func(*values),  # Discards the path arg.
#    1431       *inputs,
#    1432       **kwargs)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\internal\batch_shape_lib.py:139, in get_batch_shape_tensor_part(x, event_ndims)
#     137 else:
#     138   base_shape = tf.shape(x)
# --> 139 return _truncate_shape_tensor(base_shape, event_ndims)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow_probability\python\internal\batch_shape_lib.py:180, in _truncate_shape_tensor(shape, rightmost_ndims_to_truncate)
#     177 rightmost_ndims_to_truncate = ps.convert_to_shape_tensor(
#     178     rightmost_ndims_to_truncate, dtype_hint=np.int32)
#     179 base_rank = ps.rank_from_shape(shape)
# --> 180 return shape[:(
#     181     base_rank -
#     182     # Don't try to slice away more ndims than the parameter
#     183     # actually has, if that's fewer than `event_ndims` (i.e.,
#     184     # if it relies on broadcasting).
#     185     ps.minimum(rightmost_ndims_to_truncate, base_rank))]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:1096, in _slice_helper(tensor, slice_spec, var)
#    1094   var_empty = constant([], dtype=dtypes.int32)
#    1095   packed_begin = packed_end = packed_strides = var_empty
# -> 1096 return strided_slice(
#    1097     tensor,
#    1098     packed_begin,
#    1099     packed_end,
#    1100     packed_strides,
#    1101     begin_mask=begin_mask,
#    1102     end_mask=end_mask,
#    1103     shrink_axis_mask=shrink_axis_mask,
#    1104     new_axis_mask=new_axis_mask,
#    1105     ellipsis_mask=ellipsis_mask,
#    1106     var=var,
#    1107     name=name)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:1269, in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1266 if strides is None:
#    1267   strides = ones_like(begin)
# -> 1269 op = gen_array_ops.strided_slice(
#    1270     input=input_,
#    1271     begin=begin,
#    1272     end=end,
#    1273     strides=strides,
#    1274     name=name,
#    1275     begin_mask=begin_mask,
#    1276     end_mask=end_mask,
#    1277     ellipsis_mask=ellipsis_mask,
#    1278     new_axis_mask=new_axis_mask,
#    1279     shrink_axis_mask=shrink_axis_mask)
#    1281 parent_name = name
#    1283 if var is not None:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_array_ops.py:10671, in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10669 if tld.is_eager:
#   10670   try:
# > 10671     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   10672       _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10673       begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
#   10674       "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10675     return _result
#   10676   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
agent1.save_models()
agent2.save_models()
agent3.save_models()

# %%
file = open('mltxt.txt', 'w')
file.close()
