# %%
#MATLAB CODE
'''
function [sys,x0,str,tss]=cstr1(t,x,u,flag,Param,X_ss)

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

%
% An s-function to model a simple CSTR with first order kinetics and the following
% reaction ( A + D --> B) and ( A --> C) with a variable height well mixed vessel.  The equations that describe
% the system are:
% dV/dt  = F_in - F
% R1     = k1*Cd*Ca
% R2     = k2*Ca
% dCa/dt = F_in/V*(Ca_in-Ca)-R1-R2
% dCb/dt = F_in/V*(Cb_in-Cb)+R1
% dCc/dt = F_in/V*(Cc_in-Cc)+R2
% dCd/dt = F_in/V*(Cd_in-Cd)-R1
% dT /dt = - T/V*(F_in - F) + 1/V *(F_in*T_in - F*T) + 1/d/Cp*(-DH1)*R1+ 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*U*A*(Tc - T)

%================================================================================

switch flag,

case 0,	% Initialize the states and sizes
   [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);
   
        % ****************
  	%  Outputs
  	% ****************   
     
case 3,   % Calculate the outputs

sys = mdlOutputs(t,x,u,Param);
   
   % ****************
   % Update
   % ****************
case 1,	% Obtain derivatives of states
   
   sys = mdlDerivatives(t,x,u,Param);

otherwise,
   sys = [];
end

% ******************************************
% Sub-routines or Functions
% ******************************************

% ******************************************
% Initialization
% ******************************************
function [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

% This handles initialization of the function.
% Call simsize of a sizes structure.
sizes = simsizes;
sizes.NumContStates  = 6;     % continuous states
sizes.NumDiscStates  = 0;     % discrete states
sizes.NumOutputs     = 7;     % outputs of model (manipulated variables)
sizes.NumInputs      = 9;     % inputs of model [r;Y;Ud]
sizes.DirFeedthrough = 1;     % System is not causal, there is explicit dependence of outputs on inputs.
sizes.NumSampleTimes = 1;     %
sys = simsizes(sizes);        %
x0  = X_ss;                   % Initialize the discrete states (inputs).
str = [];	                  % set str to an empty matrix.
tss = [0,0];	              % sample time: [period, offset].

% ******************************************
%  Outputs
% ******************************************
function sys = mdlOutputs(t,x,u,Param);

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;


SWITCH = Param(1);
% entering flow
F_in = u(1)+5;
% exiting volumetric flow
F    =u(7)+5;

% outputs:
sys(1) = x(1);
sys(2) = F;
sys(3) = x(2);
sys(4) = x(3);
sys(5) = x(4);
sys(6) = x(5);
sys(7) = x(6);
% sys(8) = (PB*F*x(3)+PC*F*x(5)-PA*F*(u(2)+1)-PD*F*(u(8)+1)-PHEAT*(UA*((u(4)+200)-x(4))));

% ******************************************
% Derivatives
% ******************************************
function sys = mdlDerivatives(t,x,u,Param)

global d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;

% External Parameters:
% [0;1;-1000;1;1;25;21500;10;-1000;91500],

SWITCH = Param(1);
k01    = u(9)+1;
DH1    = Param(3);
d      = Param(4);
Cp     = Param(5);
UA     = Param(6);
EA1    = Param(7);
k02    = Param(8);
DH2    = Param(9);
EA2    = Param(10);

% Inputs (Disturbances):
% entering flow
F_in = u(1)+5;
% Entering concentration of A:
Ca   = u(2)+1;
% Entering concentration of B:
Cb   = u(3);
% Coolant Temperature in Jacket:
Tc   = u(4)+200;
% Entering concentration of C:
Cc   = u(5);

% Inputs (Manipulated Variables):
% exiting volumetric flow
F    = u(7)+5;
% Feed Temperature
T_in = u(6)+140;

% Entering Concentration of D
Cd = u(8)+1;

% Derivatives:
V = x(1);
k1 = k01 * exp (-EA1/8.314/(1.8*x(4)+1000));
k2 = k02 * exp (-EA2/8.314/(2.8*x(4)+1000));
R1 = k1*x(6)*x(2);
R2 = k2*x(2);
sys(1) = F_in - F;
sys(2) = F_in/V*(Ca-x(2))-R1-R2;
sys(3) = F_in/V*(Cb-x(3))+R1;
sys(4) = - x(4)/V*(F_in - F) + 1/V *(F_in*T_in - F*x(4)) + 1/d/Cp*(-DH1)*R1 + 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*UA*(Tc - x(4));
sys(5) = F_in/V*(Cc-x(5))+R2;
sys(6) = F_in/V*(Cd-x(6))-R1;
'''
# Out:
# '\nfunction [sys,x0,str,tss]=cstr1(t,x,u,flag,Param,X_ss)\n\nglobal d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;\n\n%\n% An s-function to model a simple CSTR with first order kinetics and the following\n% reaction ( A + D --> B) and ( A --> C) with a variable height well mixed vessel.  The equations that describe\n% the system are:\n% dV/dt  = F_in - F\n% R1     = k1*Cd*Ca\n% R2     = k2*Ca\n% dCa/dt = F_in/V*(Ca_in-Ca)-R1-R2\n% dCb/dt = F_in/V*(Cb_in-Cb)+R1\n% dCc/dt = F_in/V*(Cc_in-Cc)+R2\n% dCd/dt = F_in/V*(Cd_in-Cd)-R1\n% dT /dt = - T/V*(F_in - F) + 1/V *(F_in*T_in - F*T) + 1/d/Cp*(-DH1)*R1+ 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*U*A*(Tc - T)\n\n%================================================================================\n\nswitch flag,\n\ncase 0,\t% Initialize the states and sizes\n   [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);\n   \n        % ****************\n  \t%  Outputs\n  \t% ****************   \n     \ncase 3,   % Calculate the outputs\n\nsys = mdlOutputs(t,x,u,Param);\n   \n   % ****************\n   % Update\n   % ****************\ncase 1,\t% Obtain derivatives of states\n   \n   sys = mdlDerivatives(t,x,u,Param);\n\notherwise,\n   sys = [];\nend\n\n% ******************************************\n% Sub-routines or Functions\n% ******************************************\n\n% ******************************************\n% Initialization\n% ******************************************\nfunction [sys,x0,str,tss] = mdlInitialSizes(t,x,u,X_ss);\n\nglobal d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;\n\n% This handles initialization of the function.\n% Call simsize of a sizes structure.\nsizes = simsizes;\nsizes.NumContStates  = 6;     % continuous states\nsizes.NumDiscStates  = 0;     % discrete states\nsizes.NumOutputs     = 7;     % outputs of model (manipulated variables)\nsizes.NumInputs      = 9;     % inputs of model [r;Y;Ud]\nsizes.DirFeedthrough = 1;     % System is not causal, there is explicit dependence of outputs on inputs.\nsizes.NumSampleTimes = 1;     %\nsys = simsizes(sizes);        %\nx0  = X_ss;                   % Initialize the discrete states (inputs).\nstr = [];\t                  % set str to an empty matrix.\ntss = [0,0];\t              % sample time: [period, offset].\n\n% ******************************************\n%  Outputs\n% ******************************************\nfunction sys = mdlOutputs(t,x,u,Param);\n\nglobal d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;\n\n\nSWITCH = Param(1);\n% entering flow\nF_in = u(1)+5;\n% exiting volumetric flow\nF    =u(7)+5;\n\n% outputs:\nsys(1) = x(1);\nsys(2) = F;\nsys(3) = x(2);\nsys(4) = x(3);\nsys(5) = x(4);\nsys(6) = x(5);\nsys(7) = x(6);\n% sys(8) = (PB*F*x(3)+PC*F*x(5)-PA*F*(u(2)+1)-PD*F*(u(8)+1)-PHEAT*(UA*((u(4)+200)-x(4))));\n\n% ******************************************\n% Derivatives\n% ******************************************\nfunction sys = mdlDerivatives(t,x,u,Param)\n\nglobal d cp V CAin DH1 DH2 UA k01 k02 EA1 EA2 Tin F Tu CDin PA PB PC PD PHEAT y0 r X0;\n\n% External Parameters:\n% [0;1;-1000;1;1;25;21500;10;-1000;91500],\n\nSWITCH = Param(1);\nk01    = u(9)+1;\nDH1    = Param(3);\nd      = Param(4);\nCp     = Param(5);\nUA     = Param(6);\nEA1    = Param(7);\nk02    = Param(8);\nDH2    = Param(9);\nEA2    = Param(10);\n\n% Inputs (Disturbances):\n% entering flow\nF_in = u(1)+5;\n% Entering concentration of A:\nCa   = u(2)+1;\n% Entering concentration of B:\nCb   = u(3);\n% Coolant Temperature in Jacket:\nTc   = u(4)+200;\n% Entering concentration of C:\nCc   = u(5);\n\n% Inputs (Manipulated Variables):\n% exiting volumetric flow\nF    = u(7)+5;\n% Feed Temperature\nT_in = u(6)+140;\n\n% Entering Concentration of D\nCd = u(8)+1;\n\n% Derivatives:\nV = x(1);\nk1 = k01 * exp (-EA1/8.314/(1.8*x(4)+1000));\nk2 = k02 * exp (-EA2/8.314/(2.8*x(4)+1000));\nR1 = k1*x(6)*x(2);\nR2 = k2*x(2);\nsys(1) = F_in - F;\nsys(2) = F_in/V*(Ca-x(2))-R1-R2;\nsys( ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def cstr_model(x,t,parameters):
    #reaction ( A + D --> B) and ( A --> C)
    k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in  = parameters
    
   
    
    k1 =k01 * np.exp (-EA1/8.314/(1.8*x[3]+1000))        
    k2 =k02 * np.exp (-EA2/8.314/(2.8*x[3]+1000))        
    
    
  
    V= x[0]
    Ca= x[1]
    Cb= x[2]
    T= x[3]
    Cc= x[4]
    Cd= x[5]
    
    R1 = k1 *Ca*Cd
    R2 = k2*Ca
    
    
    dVdt  =  F_in-F
    dCadt = (F_in/V*(Ca_in-Ca))-R1-R2
    
    dCbdt =(F_in/V*(Cb_in-Cb))+R1
    
    dTdt = - T/V*(F_in - F) + 1/V *(F_in*T_in - F*T) + 1/d/Cp*(-DH1)*R1 + 1/d/Cp*(-DH2)*R2 + 1/V/d/Cp*UA*(Tc - T)
    
    dCcdt = (F_in/V*(Cc_in- Cc))+R2
    dCddt=(F_in/V*(Cd_in-Cd))-R1
   
    
    
    return [  dVdt, dCadt,dCbdt,dTdt,dCcdt,dCddt] #COnc out

# %%
def pp_random_walk():
    dims = 1
    step_n = 4000
    step_set = [-1, 0, 1]
    origin = np.zeros((1,dims))
    # Simulate steps in 1D
    step_shape = (step_n,dims)
    steps = np.random.choice(a=step_set, size=step_shape)
    path = np.concatenate([origin, steps]).cumsum(0)
    
    return path
def av(path, fluc_price):
    
 
    x1 = path[:1000]
    x2 = path[1000:2000]
    x3 = path[2000:3000]
    x4 = path[3000:]
    catch = [x1,x2,x3,x4]
    con = []
    for i in range(len(catch)):
        y = 0
        for i2 in range(len(catch[i])):
            y += catch[i][i2]
        av = y/len(catch[i])
        con.append(av)
    
    #print(con)

    maxr = 0
    for i in range(len(con)):
        if abs(maxr) < abs(con[i]):
            maxr = con[i]
    #print(maxr)
    
    if fluc_price > maxr:
        range_ = fluc_price/maxr 
        pl = np.ones(4000)
        pl[:1000] = (con[0] *range_ )
        pl[1000:2000] = (con[1]*range_ )
        pl[2000:3000] = (con[2]*range_ )
        pl[3000:] = (con[3]*range_ )
    else:
        print(maxr)
        maxr = maxr*-1
        range_ =fluc_price/maxr #maxr /fluc_price
        pl = np.ones(4000)
        pl[:1000] = (con[0] *range_ )
        pl[1000:2000] = (con[1]*range_ )
        pl[2000:3000] = (con[2]*range_ )
        pl[3000:] = (con[3]*range_ )
    
        
    return pl

# %%
def av1(path, fluc_price):
    
    x1 = path[:1333]
    x2 = path[1333:2666]
    x3 = path[2666:]
 
    catch = [x1,x2,x3]
    con = []
    for i in range(len(catch)):
        y = 0
        for i2 in range(len(catch[i])):
            y += catch[i][i2]
        av = y/len(catch[i])
        con.append(av)
    
    #print(con)

    maxr = 0
    for i in range(len(con)):
        if abs(maxr) < abs(con[i]):
            maxr = con[i]
    #print(maxr)
    
    if fluc_price > maxr:
        range_ = fluc_price/maxr
        pl = np.ones(4000)
        pl[:1333] = (con[0] *range_ )
        pl[1333:2666] = (con[1]*range_ )
        pl[2666:] = (con[2]*range_ )
      
    else:
        #maxr = maxr*-1
        range_ =maxr /fluc_price
        pl = np.ones(4000)
        pl[:1333] = (con[0] /range_ )
        pl[1333:2666] = (con[1]/range_ )
        pl[2666:] = (con[2] /range_ )
       
    
        
    return pl

# %%
import numpy as np
import random

# %%
class ChemEnv():
    def __init__(self,disturbance): #initalise with the disturbances and add them to simulate_react at certain timesteps
       
       
        self.T_disturbance = disturbance[0]
        self.Ca_disturbance = disturbance[4]
        self.p_disturbance = [disturbance[1],disturbance[2],disturbance[3]]
        
        self.state = None
        self.done = False
        
        #self.episode_length= 4000
    def step(self, action,episode_timestep,old_inputs,concs_T_V,prices,bounds): #what we do when we take a step
        new_inputs = simulate_inputs(self.reset,action,episode_timestep,old_inputs, self.T_disturbance, self.Ca_disturbance,bounds)
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = new_inputs
        
        new_concs_T_V = simulate_react(self.reset,episode_timestep,new_inputs,concs_T_V)
        
        self.current_V = new_concs_T_V[0][episode_timestep]
        self.current_Ca = new_concs_T_V[1][episode_timestep]
        self.current_Cb = new_concs_T_V[2][episode_timestep]
        self.current_T = new_concs_T_V[3][episode_timestep]
        self.current_Cc = new_concs_T_V[4][episode_timestep]
        self.current_Cd = new_concs_T_V[5][episode_timestep]
        profitt, Ca_p, Cb_p, Cc_p = profit_(new_concs_T_V,prices,episode_timestep, self.p_disturbance, new_inputs)
        
        self.episode_timestep = episode_timestep
        self.current_Tc = Tc[episode_timestep]
        self.current_T_in = T_in[episode_timestep]
        self.current_Ca_price = Ca_p
        self.current_Cb_price = Cb_p
        self.current_Cc_price = Cc_p
        self.current_Ca_in = Ca_in[episode_timestep]
        self.current_Cd_in = Cd_in[episode_timestep]
        self.current_F_in = F_in[episode_timestep]
   
        if self.episode_timestep == int(3998):
            self.done = True
            print(self.reward)
        else:
            self.done = False
            profit =profitt
        
        done = self.done
        self.reward += profitt
        self.reward1 = profitt
      
        self.state = ( new_concs_T_V,new_inputs, profitt  )
        #set placeholder for info
        info = {}
        
        #return step information
        return self.state, self.reward1, done, info
        
    def render(self): #visualisations
        #implement visualisation
        #get all current values,write to file and visualise in different python script
        with open("ml2txt.txt", "a") as myfile:
            myfile.write(f'\n{self.current_Tc},{self.current_Ca},{self.current_Cb},{self.current_T},{self.current_Cc},{self.current_Cd},{self.current_T_in},{self.current_Ca_price},{self.current_Cb_price},{self.current_Cc_price}, {self.reward},{self.current_Ca_in},{self.current_Cd_in},{self.current_F_in}')
            myfile.close()
        #pass
    def reset(self): #how we reset our enviroment
        self.reward =0
        self.reward1 =0
        input_reset = simulate_inputs(True,1,1,1,1,1,1  )
        concs_T_V = simulate_react(True, 0,input_reset,1)
        V, Ca, Cb, T, Cc, Cd = concs_T_V
        #clear contents in text file
        file = open("ml2txt.txt","r+")
        file.truncate(0)
        file.close()
        self.state = [[V, Ca, Cb,T,Cc, Cd], input_reset]
        return self.state

# %%
def simulate_inputs(reset,action, timestep, inputs,disturbance, disturbance_, bounds):
    t = np.linspace(0,4000,4000)#starting,end,how many points(from 0 to end) i used 4000 because number of episodes per batch

    if reset == True: 

        

        k01=np.ones(len(t))*1
        DH1=np.ones(len(t))*-1000
        d =np.ones(len(t))*1
        Cp=np.ones(len(t))*1
        UA=np.ones(len(t))*25
        EA1=np.ones(len(t))*21500
        k02=np.ones(len(t))*10
        DH2=np.ones(len(t))*-1000
        EA2=np.ones(len(t))*91500
        F_in=np.ones(len(t))*5
        Ca_in=np.ones(len(t))*1
        Cb_in =np.ones(len(t))*0
        Tc = np.ones(len(t))*200
        Cc_in = np.ones(len(t))*0
        F = np.ones(len(t))*5
        T_in = np.ones(len(t))*140
        Cd_in = np.ones(len(t))*1
        return [k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in]
    else:
       
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
     
         
        Ca_in[timestep:] = 1  + disturbance_[timestep]  
        Cd_in[timestep:] = min(bounds[2],max(bounds[3], Cd_in[timestep-1:timestep] + action[0])) 
        Tc[timestep:] = min(bounds[4],max(bounds[5],Tc[timestep-1:timestep] + (action[1]))) 
        F_in[timestep:] = min(bounds[0],max(bounds[1],F_in[timestep-1:timestep] + (action[2])))
        F[timestep: ] =  F_in[timestep:]
        T_in[timestep:] = 140 +  disturbance[timestep] 
        return [k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in]

# %%
def simulate_react(reset,episode_timestep,inputs,concs_T_V):
    t = np.linspace(0,4000,4000)
    if reset == True:
        i = episode_timestep
        V0 = 100
        Ca0 = 0.3038
        Cb0 = 0.534
        T0 = 306
        Cc0 = 0.162
        Cd0 = 0.466
        V  = np.ones(len(t))*V0
        Ca = np.ones(len(t))*Ca0
        Cb = np.ones(len(t))*Cb0
        T  = np.ones(len(t))*T0
        Cc = np.ones(len(t))*Cc0
        Cd = np.ones(len(t))*Cd0
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
        input_ = [k01[i],DH1[i],d[i],Cp[i],UA[i],EA1[i],k02[i],DH2[i],EA2[i],F_in[i],Ca_in[i],Cb_in[i],Tc[i],Cc_in[i],F[i],T_in[i],Cd_in[i] ]
       
        x0 = [V0,Ca0,Cb0,T0,Cc0,Cd0]
        ts = [i, i+1]
        y = odeint(cstr_model,x0,ts,args=(input_,))
        # Store results
        V[i+1]  = y[-1][0]
        Ca[i+1] = y[-1][1]
        Cb[i+1] = y[-1][2] 
        T[i+1]  = y[-1][3]
        Cc[i+1]  = y[-1][4]
        Cd[i+1]  = y[-1][5]
        dChangedt = y[-1]
        concs_T_V = V,Ca,Cb,T,Cc,Cd 
        return concs_T_V #[dChangedt]
    else:
        i = episode_timestep
        k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
        input_ = [k01[i],DH1[i],d[i],Cp[i],UA[i],EA1[i],k02[i],DH2[i],EA2[i],F_in[i],Ca_in[i],Cb_in[i],Tc[i],Cc_in[i],F[i],T_in[i],Cd_in[i] ]
        
        V,Ca,Cb,T,Cc,Cd = concs_T_V
        x = [V[i],Ca[i],Cb[i],T[i],Cc[i],Cd[i]]
        ts = [i, i+1]
        y = odeint(cstr_model,x,ts,args=(input_,))
        # Store results
        V[i+1]  = y[-1][0]
        Ca[i+1] = y[-1][1]
        Cb[i+1] = y[-1][2] 
        T[i+1]  = y[-1][3]
        Cc[i+1]  = y[-1][4]
        Cd[i+1]  = y[-1][5]
        dChangedt = y[-1]
        concs_T_V = V,Ca,Cb,T,Cc,Cd  
        
        return concs_T_V

# %%
def profit_(concs_T_V, prices, episode_timestep, price_disturbance, new_inputs):
    i = episode_timestep
    V,Ca,Cb,T,Cc,Cd = concs_T_V
    price_Ca,price_Cb,price_Cc,price_Cd,price_heat= prices
    disturb_Ca, disturb_Cb, disturb_Cc  =price_disturbance
    k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = new_inputs
    
    F_in = F_in[i]
    UA =25
    Ca_in = Ca_in[i]
    Cd_in = Cd_in[i]
    Cb = Cb[ i]
    T = T[i]

    Cc = Cc[ i]
    price_Ca = price_Ca + disturb_Ca[i]
    price_Cb = price_Cb + disturb_Cb[i]
    price_Cc = price_Cc + disturb_Cc[i]
    
    temp_cost = (price_heat*UA*(Tc[i]-T))
    Ca_cost = (price_Ca* Ca_in)
    Cd_cost = (price_Cd* Cd_in)
    delta_Tc = 200-Tc[i]
    penalty_T1 = (100*tf.math.tanh(T-800))+100  
    penalty_T2 = (100*tf.math.tanh(-T+100))+100 
    penalty_CC = (100*tf.math.tanh(-Cc+0.1))+100
    penalty_CB = (100*tf.math.tanh(-Cb+0.1))+100
    total_penalty =  penalty_T1 +  penalty_T2  + penalty_CC+ penalty_CB
 

    
    
    profit = F_in*(((Cb*price_Cb)+ (Cc*price_Cc)) -((price_Ca* Ca_in)+(price_Cd* Cd_in))) + temp_cost
    
    
    
    profit_ = (profit)-(0.1*total_penalty)
   
    return [profit_,price_Ca,price_Cb,price_Cc]

# %%
def disturbance_generator(episode, number_of_episodes):
    prices = [5, 12, 19, 2, 0.001]
    i1 = 0.1
    i2 = 0.01
    i3 = 0.3
    
    power = (episode/number_of_episodes)*10
    
    ca_disturb_bound = 1*((1+i2)**power)
    ca_disturb_bound = min(ca_disturb_bound,2)
    cb_disturb_bound = 1*((1+i1)**power)
    cb_disturb_bound = min(cb_disturb_bound,8)
    cc_disturb_bound = 1*((1+i1)**power)
    cc_disturb_bound = min(cc_disturb_bound,9)
    cc_disturb_bound *=-1
    ca_in_disturb_bound =0.15*((1+i3)**power)
    ca_in_disturb_bound = min( ca_in_disturb_bound,0.4)
    ###T-disturbance
    sr=0.05
    ts = 1.0/sr
    t = np.arange(0,80000,ts)
    freq = 0.00004 
    y = 60*np.sin(2*np.pi*freq*t)
    T_disturb = y
    #######Ca_disturb price
    t1 = pp_random_walk()
    Ca_disturb_price = av1(t1,ca_disturb_bound) #2
    ######Cb_disturb price
    t2 = pp_random_walk()
    Cb_disturb_price = av1(t2,cb_disturb_bound) #8
    ######Cc_disturb price
    t3 = pp_random_walk()
    Cc_disturb_price = av1(t3, cc_disturb_bound ) #-9
    ######Ca_in disturb
    t4 = pp_random_walk()
    Ca_in_disturb = av(t4, ca_in_disturb_bound)
    
    disturbs = [T_disturb,Ca_disturb_price,Cb_disturb_price,Cc_disturb_price,Ca_in_disturb]
    
    return disturbs

# %%
def test_generator(disturb):
    ############################################
    T_disturb = disturb[0]
    Ca_disturb_price = disturb[1]
    Cb_disturb_price = disturb[2]
    Cc_disturb_price = disturb[3]
    Ca_in_disturb = disturb[4]
    #############################################
    Ca_in_disturb[0:500] = 0 #1000
    Ca_in_disturb[500:2000] = 0.4#0.3 1000-2200
    Ca_in_disturb[2000:] = 0.05#0.1 2200
    #############################################
    Ca_disturb_price[0:1500] = 0 #1200
    Ca_disturb_price[1500:]=1.5#2 1200
    #############################################
    Cb_disturb_price[0:1100]= 0
    Cb_disturb_price[1100:]= 5#8
    #############################################
    Cc_disturb_price[0:1000]= 0 #420
    Cc_disturb_price[1000:]= -8#-9 #420
    ############################################
    
    return [T_disturb,Ca_disturb_price,Cb_disturb_price,Cc_disturb_price,Ca_in_disturb]

# %%
def bounds_generator(episode, number_of_episodes):
    upper_F = 15
    lower_F = 12
    upper_Cd = 0.6
    lower_Cd = 0.2
    upper_T = 375
    lower_T = 350
    upper_r = 0.5
    lower_r = 0.6
 
    power = (episode/number_of_episodes)*10
    upper_F = upper_F*((1+upper_r)**power)
    upper_F = min(25,upper_F)
    upper_Cd = upper_Cd*((1+upper_r)**power)
    upper_Cd = min(5,upper_Cd)
    upper_T = upper_T*((1+upper_r)**power)
    upper_T = min(550,upper_T)
    #################################################
    lower_F = lower_F*((1+lower_r)**-power)
    lower_F = max(1,lower_F)
    lower_Cd = lower_Cd*((1+lower_r)**-power)
    lower_Cd = max(0.001,lower_Cd)
    lower_T =lower_T*((1+lower_r)**-power)
    lower_T = max(280,lower_T)
    
    return [upper_F,lower_F,upper_Cd,lower_Cd,upper_T,lower_T] #[upper_F,lower_F,upper_Cd,lower_Cd,upper_T,lower_T]#[25,1,5,0.001,550,280]

# %%
import import_ipynb
from ipynb.fs.full.S_A_C_1A import Agent
import numpy as np
# Out:
# importing Jupyter notebook from Experience_Replay.ipynb

# %%
#!pip install ipynb

# %%
import math as m
agent = Agent()
score_catcher = []
avg_catcher = []
agg = []

# %%
import tensorflow as tf

# %%
agent.load_models()
# Out:
# ... loading models ...

# %%
prices = [5, 12, 19, 2, 0.001] #Ca,Cb,Cc,Cd #19
r = []
r1 = []
score = 0
max_ = 0
number_episodes =250
alpha_beg = 0.99
ir = 0.2
for epi in range(number_episodes):
    bounds = bounds_generator(epi,number_episodes)
    if epi == 0:
        disturbs = disturbance_generator(epi,number_episodes)
        #test_disturb = test_generator(disturbs)
        #env = ChemEnv(test_disturb)
        env = ChemEnv(disturbs)
    elif epi % 15 == 0:
        disturbs = disturbance_generator(epi,number_episodes)
        #test_disturb = test_generator(disturbs)
        #env = ChemEnv(test_disturb)
        env = ChemEnv(disturbs) #new disturbances
    else:
        pass #same disturbances as before
    timesteps = 4000
    current_state =env.reset()
    obs = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5],current_state[1][-2],(5+disturbs[1][0])/5,(12+disturbs[2][0])/12,(19+disturbs[3][0])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]])#.astype('float32') 
    start = True
    score = 0
    alpha = alpha_beg*((1+ir)**((-epi/number_episodes)*10))
    for timestep in range(1,timesteps-1):
        action = agent.choose_action([obs],timestep,start)
        step = env.step(action,timestep,current_state[1],current_state[0],prices,bounds)
        env.render()
        current_state = [step[0][0],step[0][1]]

        obs_ = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5], current_state[1][-2],(5+disturbs[1][timestep])/5, (12+disturbs[2][timestep])/12,(19+disturbs[2][timestep])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]]) #current_state[1][-2]#.astype('float32')
        s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12  = obs
        obs_r = np.array([s1[timestep], s2[timestep], s3[timestep]/1000, s4[timestep], s5[timestep],s6[timestep]/1000,s7,s8,s9,s10[timestep]/1000,s11[timestep],s12[timestep]])
        s1a,s2a,s3a,s4a,s5a,s6a,s7a,s8a,s9a, s10a,s11a,s12a  = obs_
        obs_r_ = np.array([s1a[timestep], s2a[timestep], s3a[timestep]/1000, s4a[timestep], s5a[timestep],s6a[timestep]/1000,s7a,s8a,s9a,s10a[timestep]/1000,s11a[timestep],s12a[timestep]])
        reward = step[1]
        done = step[2]
        agent.remember(obs_r, action, reward, obs_r_, done)
        obs = obs_
        score += reward
        start = False
        r.append(score)
       
    agent.learn(alpha)
    
    r1.append(score)
    avg_s = np.mean(r[-4000:])
    avg_catcher.append(avg_s)
 
    print(avg_s)
# Out:
# C:\Users\simso\AppData\Local\Temp\ipykernel_9904\444610906.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   obs = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5],current_state[1][-2],(5+disturbs[1][0])/5,(12+disturbs[2][0])/12,(19+disturbs[3][0])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]])#.astype('float32')
# C:\Users\simso\AppData\Local\Temp\ipykernel_9904\444610906.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   obs_ = np.array([current_state[0][1], current_state[0][2],current_state[0][3],current_state[0][4],current_state[0][5], current_state[1][-2],(5+disturbs[1][timestep])/5, (12+disturbs[2][timestep])/12,(19+disturbs[2][timestep])/19,current_state[1][-5],current_state[1][-1],current_state[1][-7]]) #current_state[1][-2]#.astype('float32')
# tf.Tensor(-9484.089508935962, shape=(), dtype=float64)
# -722.2680808845486
# tf.Tensor(-17010.391803083363, shape=(), dtype=float64)
# -4457.466123042653
# tf.Tensor(-24360.078200237647, shape=(), dtype=float64)
# tf.Tensor(6.912141, shape=(), dtype=float32)
# tf.Tensor(-4.9344864, shape=(), dtype=float32)
# tf.Tensor(0.004556721, shape=(), dtype=float32)
# -8103.909330777735
# tf.Tensor(-21813.106537630014, shape=(), dtype=float64)
# tf.Tensor(6.7059116, shape=(), dtype=float32)
# tf.Tensor(-4.5387497, shape=(), dtype=float32)
# tf.Tensor(0.005599846, shape=(), dtype=float32)
# -6252.709021152309
# tf.Tensor(88427.73430667842, shape=(), dtype=float64)
# tf.Tensor(8.002827, shape=(), dtype=float32)
# tf.Tensor(2.4939475, shape=(), dtype=float32)
# tf.Tensor(0.005819531, shape=(), dtype=float32)
# 44587.98742900213
# tf.Tensor(96247.33045226001, shape=(), dtype=float64)
# tf.Tensor(7.89203, shape=(), dtype=float32)
# tf.Tensor(5.1270027, shape=(), dtype=float32)
# tf.Tensor(0.0061713755, shape=(), dtype=float32)
# 48631.64429289036
# tf.Tensor(102152.71907370214, shape=(), dtype=float64)
# tf.Tensor(7.2677817, shape=(), dtype=float32)
# tf.Tensor(6.938366, shape=(), dtype=float32)
# tf.Tensor(0.0055714324, shape=(), dtype=float32)
# 51254.57243678992
# tf.Tensor(108310.65739720801, shape=(), dtype=float64)
# tf.Tensor(6.500103, shape=(), dtype=float32)
# tf.Tensor(11.812441, shape=(), dtype=float32)
# tf.Tensor(0.0065854583, shape=(), dtype=float32)
# 54282.04682474458
# tf.Tensor(108707.29356921994, shape=(), dtype=float64)
# tf.Tensor(5.6225805, shape=(), dtype=float32)
# tf.Tensor(10.755634, shape=(), dtype=float32)
# tf.Tensor(0.0065430054, shape=(), dtype=float32)
# 52100.84454435349
# tf.Tensor(102910.94358685918, shape=(), dtype=float64)
# tf.Tensor(4.7830462, shape=(), dtype=float32)
# tf.Tensor(10.834258, shape=(), dtype=float32)
# tf.Tensor(0.0067222696, shape=(), dtype=float32)
# 45121.34881137373
# tf.Tensor(104998.90435825654, shape=(), dtype=float64)
# tf.Tensor(3.7988486, shape=(), dtype=float32)
# tf.Tensor(15.178824, shape=(), dtype=float32)
# tf.Tensor(0.007031768, shape=(), dtype=float32)
# 45466.0840604828
# tf.Tensor(118865.35039389851, shape=(), dtype=float64)
# tf.Tensor(2.6337667, shape=(), dtype=float32)
# tf.Tensor(17.62835, shape=(), dtype=float32)
# tf.Tensor(0.0069600055, shape=(), dtype=float32)
# 53996.30339426668
# tf.Tensor(128988.11207459633, shape=(), dtype=float64)
# tf.Tensor(1.3195685, shape=(), dtype=float32)
# tf.Tensor(16.461733, shape=(), dtype=float32)
# tf.Tensor(0.007230159, shape=(), dtype=float32)
# 60076.39979812179
# tf.Tensor(138942.07130326753, shape=(), dtype=float64)
# tf.Tensor(-0.4117104, shape=(), dtype=float32)
# tf.Tensor(19.055183, shape=(), dtype=float32)
# tf.Tensor(0.0071827183, shape=(), dtype=float32)
# 66338.10056963962
# tf.Tensor(147310.9694716778, shape=(), dtype=float64)
# tf.Tensor(-2.6036668, shape=(), dtype=float32)
# tf.Tensor(19.286491, shape=(), dtype=float32)
# tf.Tensor(0.0070054205, shape=(), dtype=float32)
# 71314.42236637755
# [61.27372627]
# tf.Tensor(57113.991885914395, shape=(), dtype=float64)
# tf.Tensor(-5.16713, shape=(), dtype=float32)
# tf.Tensor(19.228474, shape=(), dtype=float32)
# tf.Tensor(0.007170256, shape=(), dtype=float32)
# 39838.91248764989
# tf.Tensor(60030.27430722854, shape=(), dtype=float64)
# tf.Tensor(-8.415138, shape=(), dtype=float32)
# tf.Tensor(18.517551, shape=(), dtype=float32)
# tf.Tensor(0.0069198813, shape=(), dtype=float32)
# 41001.9735674268
# tf.Tensor(64240.397097648434, shape=(), dtype=float64)
# tf.Tensor(-12.570988, shape=(), dtype=float32)
# tf.Tensor(21.656673, shape=(), dtype=float32)
# tf.Tensor(0.006603646, shape=(), dtype=float32)
# 43447.64407283995
# tf.Tensor(69965.29794647766, shape=(), dtype=float64)
# tf.Tensor(-17.151894, shape=(), dtype=float32)
# tf.Tensor(18.12268, shape=(), dtype=float32)
# tf.Tensor(0.0059359153, shape=(), dtype=float32)
# 47311.67730652519
# tf.Tensor(74126.93902185923, shape=(), dtype=float64)
# tf.Tensor(-21.797451, shape=(), dtype=float32)
# tf.Tensor(18.55724, shape=(), dtype=float32)
# tf.Tensor(0.005825881, shape=(), dtype=float32)
# 49728.381990517286
# tf.Tensor(79115.81144227319, shape=(), dtype=float64)
# tf.Tensor(-25.257725, shape=(), dtype=float32)
# tf.Tensor(19.499905, shape=(), dtype=float32)
# tf.Tensor(0.006443451, shape=(), dtype=float32)
# 52964.07313101285
# tf.Tensor(83508.84776279281, shape=(), dtype=float64)
# tf.Tensor(-26.785778, shape=(), dtype=float32)
# tf.Tensor(16.478203, shape=(), dtype=float32)
# tf.Tensor(0.0054275007, shape=(), dtype=float32)
# 55674.444576643626
# tf.Tensor(86311.57883566247, shape=(), dtype=float64)
# tf.Tensor(-26.147226, shape=(), dtype=float32)
# tf.Tensor(18.203295, shape=(), dtype=float32)
# tf.Tensor(0.005272789, shape=(), dtype=float32)
# 56899.2067756742
# tf.Tensor(89266.66357105326, shape=(), dtype=float64)
# tf.Tensor(-24.529846, shape=(), dtype=float32)
# tf.Tensor(17.611198, shape=(), dtype=float32)
# tf.Tensor(0.005676968, shape=(), dtype=float32)
# 58306.10942557913
# tf.Tensor(89013.7399628707, shape=(), dtype=float64)
# tf.Tensor(-22.024227, shape=(), dtype=float32)
# tf.Tensor(18.629883, shape=(), dtype=float32)
# tf.Tensor(0.005653255, shape=(), dtype=float32)
# 57844.74118079447
# tf.Tensor(83677.6220204529, shape=(), dtype=float64)
# tf.Tensor(-19.344078, shape=(), dtype=float32)
# tf.Tensor(20.28097, shape=(), dtype=float32)
# tf.Tensor(0.0061823125, shape=(), dtype=float32)
# 54493.31199309646
# tf.Tensor(77617.37236949704, shape=(), dtype=float64)
# tf.Tensor(-16.84777, shape=(), dtype=float32)
# tf.Tensor(18.334202, shape=(), dtype=float32)
# tf.Tensor(0.0061500613, shape=(), dtype=float32)
# 50537.676071003734
# tf.Tensor(75051.25750413151, shape=(), dtype=float64)
# tf.Tensor(-14.84204, shape=(), dtype=float32)
# tf.Tensor(20.25864, shape=(), dtype=float32)
# tf.Tensor(0.0063799173, shape=(), dtype=float32)
# 49815.746705533435
# tf.Tensor(72159.37882579457, shape=(), dtype=float64)
# tf.Tensor(-13.079385, shape=(), dtype=float32)
# tf.Tensor(20.207956, shape=(), dtype=float32)
# tf.Tensor(0.0067659677, shape=(), dtype=float32)
# 48880.47519477741
# tf.Tensor(68647.65626292024, shape=(), dtype=float64)
# tf.Tensor(-11.763613, shape=(), dtype=float32)
# tf.Tensor(20.344395, shape=(), dtype=float32)
# tf.Tensor(0.0066493447, shape=(), dtype=float32)
# 47482.41633920572
# tf.Tensor(143711.45253080362, shape=(), dtype=float64)
# tf.Tensor(-10.732532, shape=(), dtype=float32)
# tf.Tensor(18.04232, shape=(), dtype=float32)
# tf.Tensor(0.0072969077, shape=(), dtype=float32)
# 48638.58363724949
# tf.Tensor(140329.53049707483, shape=(), dtype=float64)
# tf.Tensor(-10.72911, shape=(), dtype=float32)
# tf.Tensor(22.993998, shape=(), dtype=float32)
# tf.Tensor(0.007898517, shape=(), dtype=float32)
# 46780.20804690189
# tf.Tensor(137282.52079216656, shape=(), dtype=float64)
# tf.Tensor(-10.900335, shape=(), dtype=float32)
# tf.Tensor(21.475574, shape=(), dtype=float32)
# tf.Tensor(0.0076484783, shape=(), dtype=float32)
# 44622.44843074969
# tf.Tensor(135612.2588579412, shape=(), dtype=float64)
# tf.Tensor(-11.599869, shape=(), dtype=float32)
# tf.Tensor(21.612677, shape=(), dtype=float32)
# tf.Tensor(0.008259786, shape=(), dtype=float32)
# 43196.02115749847
# tf.Tensor(133376.29478661067, shape=(), dtype=float64)
# tf.Tensor(-12.534374, shape=(), dtype=float32)
# tf.Tensor(22.684214, shape=(), dtype=float32)
# tf.Tensor(0.009221348, shape=(), dtype=float32)
# 41296.5146971791
# tf.Tensor(131045.20112834376, shape=(), dtype=float64)
# tf.Tensor(-13.540559, shape=(), dtype=float32)
# tf.Tensor(19.74321, shape=(), dtype=float32)
# tf.Tensor(0.010525297, shape=(), dtype=float32)
# 39378.694719613835
# tf.Tensor(134349.74740130335, shape=(), dtype=float64)
# tf.Tensor(-15.268673, shape=(), dtype=float32)
# tf.Tensor(20.272846, shape=(), dtype=float32)
# tf.Tensor(0.009102218, shape=(), dtype=float32)
# 42385.23807247117
# tf.Tensor(137717.6436600075, shape=(), dtype=float64)
# tf.Tensor(-16.948298, shape=(), dtype=float32)
# tf.Tensor(24.48203, shape=(), dtype=float32)
# tf.Tensor(0.01129202, shape=(), dtype=float32)
# 45571.11698836579
# tf.Tensor(139892.16576020382, shape=(), dtype=float64)
# tf.Tensor(-18.725567, shape=(), dtype=float32)
# tf.Tensor(21.253475, shape=(), dtype=float32)
# tf.Tensor(0.010508038, shape=(), dtype=float32)
# 47796.84161025948
# tf.Tensor(139966.05283459267, shape=(), dtype=float64)
# tf.Tensor(-20.318285, shape=(), dtype=float32)
# tf.Tensor(23.781418, shape=(), dtype=float32)
# tf.Tensor(0.010785867, shape=(), dtype=float32)
# 48091.080658332394
# tf.Tensor(139976.2999623901, shape=(), dtype=float64)
# tf.Tensor(-22.248936, shape=(), dtype=float32)
# tf.Tensor(24.152071, shape=(), dtype=float32)
# tf.Tensor(0.012355071, shape=(), dtype=float32)
# 48384.16355532503
# tf.Tensor(138512.42322296824, shape=(), dtype=float64)
# tf.Tensor(-23.578714, shape=(), dtype=float32)
# tf.Tensor(20.505575, shape=(), dtype=float32)
# tf.Tensor(0.013179329, shape=(), dtype=float32)
# 47423.93262904551
# tf.Tensor(137526.16313650698, shape=(), dtype=float64)
# tf.Tensor(-24.059834, shape=(), dtype=float32)
# tf.Tensor(21.514814, shape=(), dtype=float32)
# tf.Tensor(0.0148823885, shape=(), dtype=float32)
# 47095.23831261863
# tf.Tensor(136310.09260072795, shape=(), dtype=float64)
# tf.Tensor(-24.195105, shape=(), dtype=float32)
# tf.Tensor(24.203613, shape=(), dtype=float32)
# tf.Tensor(0.0125474855, shape=(), dtype=float32)
# 46606.12164214501
# tf.Tensor(135213.8678758083, shape=(), dtype=float64)
# tf.Tensor(-24.231699, shape=(), dtype=float32)
# tf.Tensor(25.344725, shape=(), dtype=float32)
# tf.Tensor(0.016842876, shape=(), dtype=float32)
# 46233.068461087365
# tf.Tensor(298435.574174396, shape=(), dtype=float64)
# tf.Tensor(-23.327866, shape=(), dtype=float32)
# tf.Tensor(24.114964, shape=(), dtype=float32)
# tf.Tensor(0.014713848, shape=(), dtype=float32)
# 179710.90744245314
# tf.Tensor(295175.23105486954, shape=(), dtype=float64)
# tf.Tensor(-23.15406, shape=(), dtype=float32)
# tf.Tensor(29.836796, shape=(), dtype=float32)
# tf.Tensor(0.01791327, shape=(), dtype=float32)
# 177259.6123094991
# tf.Tensor(294505.38483635074, shape=(), dtype=float64)
# tf.Tensor(-23.153875, shape=(), dtype=float32)
# tf.Tensor(26.61504, shape=(), dtype=float32)
# tf.Tensor(0.01813532, shape=(), dtype=float32)
# 177183.1321646425
# tf.Tensor(293893.64507468324, shape=(), dtype=float64)
# tf.Tensor(-23.694672, shape=(), dtype=float32)
# tf.Tensor(27.793789, shape=(), dtype=float32)
# tf.Tensor(0.018819705, shape=(), dtype=float32)
# 177204.68700324613
# tf.Tensor(292212.97844300384, shape=(), dtype=float64)
# tf.Tensor(-24.5103, shape=(), dtype=float32)
# tf.Tensor(29.615065, shape=(), dtype=float32)
# tf.Tensor(0.019369107, shape=(), dtype=float32)
# 176243.59700646275
# tf.Tensor(290328.2264298882, shape=(), dtype=float64)
# tf.Tensor(-25.484753, shape=(), dtype=float32)
# tf.Tensor(28.037373, shape=(), dtype=float32)
# tf.Tensor(0.019431438, shape=(), dtype=float32)
# 175158.44531572924
# tf.Tensor(289972.53434753884, shape=(), dtype=float64)
# tf.Tensor(-26.903597, shape=(), dtype=float32)
# tf.Tensor(29.146076, shape=(), dtype=float32)
# tf.Tensor(0.019667774, shape=(), dtype=float32)
# 175503.2438467632
# tf.Tensor(288519.03761829523, shape=(), dtype=float64)
# tf.Tensor(-28.475224, shape=(), dtype=float32)
# tf.Tensor(30.847424, shape=(), dtype=float32)
# tf.Tensor(0.02186995, shape=(), dtype=float32)
# 174897.20717904076
# tf.Tensor(286031.63816686824, shape=(), dtype=float64)
# tf.Tensor(-30.2522, shape=(), dtype=float32)
# tf.Tensor(32.04621, shape=(), dtype=float32)
# tf.Tensor(0.021289758, shape=(), dtype=float32)
# 173344.1585337852
# tf.Tensor(284771.229631751, shape=(), dtype=float64)
# tf.Tensor(-31.94236, shape=(), dtype=float32)
# tf.Tensor(31.559074, shape=(), dtype=float32)
# tf.Tensor(0.02255607, shape=(), dtype=float32)
# 172987.38409574577
# tf.Tensor(282739.84248481726, shape=(), dtype=float64)
# tf.Tensor(-33.08976, shape=(), dtype=float32)
# tf.Tensor(34.1922, shape=(), dtype=float32)
# tf.Tensor(0.022162553, shape=(), dtype=float32)
# 171963.52285758647
# tf.Tensor(280874.9421544826, shape=(), dtype=float64)
# tf.Tensor(-34.804237, shape=(), dtype=float32)
# tf.Tensor(34.64132, shape=(), dtype=float32)
# tf.Tensor(0.023764336, shape=(), dtype=float32)
# 171128.70880232615
# tf.Tensor(277970.86200358596, shape=(), dtype=float64)
# tf.Tensor(-36.08962, shape=(), dtype=float32)
# tf.Tensor(32.733036, shape=(), dtype=float32)
# tf.Tensor(0.024591735, shape=(), dtype=float32)
# 169381.03734490002
# tf.Tensor(276249.3150880415, shape=(), dtype=float64)
# tf.Tensor(-35.550835, shape=(), dtype=float32)
# tf.Tensor(34.485863, shape=(), dtype=float32)
# tf.Tensor(0.024112005, shape=(), dtype=float32)
# 168762.0559616223
# tf.Tensor(274085.45144817454, shape=(), dtype=float64)
# tf.Tensor(-35.172836, shape=(), dtype=float32)
# tf.Tensor(33.908295, shape=(), dtype=float32)
# tf.Tensor(0.025613293, shape=(), dtype=float32)
# 167780.1693762261
# tf.Tensor(129256.98842298973, shape=(), dtype=float64)
# tf.Tensor(-34.11512, shape=(), dtype=float32)
# tf.Tensor(32.012592, shape=(), dtype=float32)
# tf.Tensor(0.02596524, shape=(), dtype=float32)
# 58311.1100995972
# tf.Tensor(126447.44001655567, shape=(), dtype=float64)
# tf.Tensor(-32.754654, shape=(), dtype=float32)
# tf.Tensor(31.58781, shape=(), dtype=float32)
# tf.Tensor(0.027512094, shape=(), dtype=float32)
# 56812.581677661496
# tf.Tensor(122020.6033930847, shape=(), dtype=float64)
# tf.Tensor(-32.05904, shape=(), dtype=float32)
# tf.Tensor(35.312675, shape=(), dtype=float32)
# tf.Tensor(0.030591689, shape=(), dtype=float32)
# 53968.50091131983
# tf.Tensor(115967.00788636223, shape=(), dtype=float64)
# tf.Tensor(-31.140556, shape=(), dtype=float32)
# tf.Tensor(34.56495, shape=(), dtype=float32)
# tf.Tensor(0.032297716, shape=(), dtype=float32)
# 49772.33203348282
# tf.Tensor(96606.93882508496, shape=(), dtype=float64)
# tf.Tensor(-30.694933, shape=(), dtype=float32)
# tf.Tensor(36.045578, shape=(), dtype=float32)
# tf.Tensor(0.030795753, shape=(), dtype=float32)
# 35240.350960446915
# tf.Tensor(-24607.863342565397, shape=(), dtype=float64)
# tf.Tensor(-34.585205, shape=(), dtype=float32)
# tf.Tensor(39.607998, shape=(), dtype=float32)
# tf.Tensor(0.032925375, shape=(), dtype=float32)
# -16526.872130398802
# tf.Tensor(-29966.583416658894, shape=(), dtype=float64)
# tf.Tensor(-37.03249, shape=(), dtype=float32)
# tf.Tensor(34.828957, shape=(), dtype=float32)
# tf.Tensor(0.036790907, shape=(), dtype=float32)
# -18796.83149022638
# tf.Tensor(-30912.881240923965, shape=(), dtype=float64)
# tf.Tensor(-40.439404, shape=(), dtype=float32)
# tf.Tensor(32.49457, shape=(), dtype=float32)
# tf.Tensor(0.037056357, shape=(), dtype=float32)
# -19350.692434358127
# tf.Tensor(-20581.51235648761, shape=(), dtype=float64)
# tf.Tensor(-39.21112, shape=(), dtype=float32)
# tf.Tensor(32.89118, shape=(), dtype=float32)
# tf.Tensor(0.036270812, shape=(), dtype=float32)
# -16659.459060094414
# tf.Tensor(79980.44953279797, shape=(), dtype=float64)
# tf.Tensor(-38.93975, shape=(), dtype=float32)
# tf.Tensor(33.373985, shape=(), dtype=float32)
# tf.Tensor(0.04360889, shape=(), dtype=float32)
# 27818.676733812244
# tf.Tensor(89419.53258699604, shape=(), dtype=float64)
# tf.Tensor(-35.490013, shape=(), dtype=float32)
# tf.Tensor(30.085201, shape=(), dtype=float32)
# tf.Tensor(0.04390753, shape=(), dtype=float32)
# 36646.800643218725
# tf.Tensor(88400.2486178234, shape=(), dtype=float64)
# tf.Tensor(-31.373692, shape=(), dtype=float32)
# tf.Tensor(33.57183, shape=(), dtype=float32)
# tf.Tensor(0.04241643, shape=(), dtype=float32)
# 37092.385962305205
# tf.Tensor(84919.75044951687, shape=(), dtype=float64)
# tf.Tensor(-28.666702, shape=(), dtype=float32)
# tf.Tensor(32.379448, shape=(), dtype=float32)
# tf.Tensor(0.042390503, shape=(), dtype=float32)
# 35389.71537827189
# tf.Tensor(80046.68219144098, shape=(), dtype=float64)
# tf.Tensor(-26.13256, shape=(), dtype=float32)
# tf.Tensor(31.240263, shape=(), dtype=float32)
# tf.Tensor(0.039665055, shape=(), dtype=float32)
# 32485.58761946714
# tf.Tensor(72587.05587940635, shape=(), dtype=float64)
# tf.Tensor(-27.529675, shape=(), dtype=float32)
# tf.Tensor(32.177574, shape=(), dtype=float32)
# tf.Tensor(0.04678165, shape=(), dtype=float32)
# 27394.877911251584
# tf.Tensor(163756.56170820555, shape=(), dtype=float64)
# tf.Tensor(-30.034042, shape=(), dtype=float32)
# tf.Tensor(30.988348, shape=(), dtype=float32)
# tf.Tensor(0.054052822, shape=(), dtype=float32)
# 38675.76018728865
# tf.Tensor(165753.59196538333, shape=(), dtype=float64)
# tf.Tensor(-32.501198, shape=(), dtype=float32)
# tf.Tensor(32.018204, shape=(), dtype=float32)
# tf.Tensor(0.05523666, shape=(), dtype=float32)
# 42025.07185157953
# tf.Tensor(163741.1807256335, shape=(), dtype=float64)
# tf.Tensor(-33.415276, shape=(), dtype=float32)
# tf.Tensor(34.28412, shape=(), dtype=float32)
# tf.Tensor(0.05028752, shape=(), dtype=float32)
# 41967.837332564966
# tf.Tensor(160328.76751122117, shape=(), dtype=float64)
# tf.Tensor(-36.10778, shape=(), dtype=float32)
# tf.Tensor(34.094215, shape=(), dtype=float32)
# tf.Tensor(0.061260708, shape=(), dtype=float32)
# 40724.903954269095
# tf.Tensor(155967.13123820987, shape=(), dtype=float64)
# tf.Tensor(-36.489067, shape=(), dtype=float32)
# tf.Tensor(32.849518, shape=(), dtype=float32)
# tf.Tensor(0.061498113, shape=(), dtype=float32)
# 38707.773234636334
# tf.Tensor(150348.46761106863, shape=(), dtype=float64)
# tf.Tensor(-35.281723, shape=(), dtype=float32)
# tf.Tensor(35.286476, shape=(), dtype=float32)
# tf.Tensor(0.056973353, shape=(), dtype=float32)
# 35821.09756617412
# tf.Tensor(144290.67521006035, shape=(), dtype=float64)
# tf.Tensor(-33.23122, shape=(), dtype=float32)
# tf.Tensor(28.632385, shape=(), dtype=float32)
# tf.Tensor(0.059230186, shape=(), dtype=float32)
# 32668.844261316062
# tf.Tensor(138440.61923310338, shape=(), dtype=float64)
# tf.Tensor(-33.194927, shape=(), dtype=float32)
# tf.Tensor(40.000793, shape=(), dtype=float32)
# tf.Tensor(0.05798225, shape=(), dtype=float32)
# 29656.689884130374
# tf.Tensor(132637.87009849143, shape=(), dtype=float64)
# tf.Tensor(-32.402565, shape=(), dtype=float32)
# tf.Tensor(29.883722, shape=(), dtype=float32)
# tf.Tensor(0.05856914, shape=(), dtype=float32)
# 26688.621357041247
# tf.Tensor(126731.07541865588, shape=(), dtype=float64)
# tf.Tensor(-32.66925, shape=(), dtype=float32)
# tf.Tensor(29.552788, shape=(), dtype=float32)
# tf.Tensor(0.06251805, shape=(), dtype=float32)
# 23653.97436019531
# tf.Tensor(120778.96462888105, shape=(), dtype=float64)
# tf.Tensor(-32.86196, shape=(), dtype=float32)
# tf.Tensor(34.951294, shape=(), dtype=float32)
# tf.Tensor(0.05511392, shape=(), dtype=float32)
# 20625.471069495754
# tf.Tensor(114537.65007336118, shape=(), dtype=float64)
# tf.Tensor(-35.205276, shape=(), dtype=float32)
# tf.Tensor(36.42466, shape=(), dtype=float32)
# tf.Tensor(0.06398451, shape=(), dtype=float32)
# 17374.431636581216
# tf.Tensor(212188.493440009, shape=(), dtype=float64)
# tf.Tensor(-38.18309, shape=(), dtype=float32)
# tf.Tensor(36.515194, shape=(), dtype=float32)
# tf.Tensor(0.06702939, shape=(), dtype=float32)
# 65041.44597635791
# tf.Tensor(147126.590231008, shape=(), dtype=float64)
# tf.Tensor(-39.13591, shape=(), dtype=float32)
# tf.Tensor(29.445263, shape=(), dtype=float32)
# tf.Tensor(0.06594023, shape=(), dtype=float32)
# 36813.619797380394
# tf.Tensor(52478.58454903551, shape=(), dtype=float64)
# tf.Tensor(-39.117752, shape=(), dtype=float32)
# tf.Tensor(32.682228, shape=(), dtype=float32)
# tf.Tensor(0.06758119, shape=(), dtype=float32)
# -17859.755100324426
# [52.492]
# tf.Tensor(-213521.46817891675, shape=(), dtype=float64)
# tf.Tensor(-34.699554, shape=(), dtype=float32)
# tf.Tensor(30.550383, shape=(), dtype=float32)
# tf.Tensor(0.06631191, shape=(), dtype=float32)
# -102249.32078367448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 9>()
#      29 for timestep in range(1,timesteps-1):
#      30     action = agent.choose_action([obs],timestep,start)
# ---> 31     step = env.step(action,timestep,current_state[1],current_state[0],prices,bounds)
#      32     env.render()
#      33     current_state = [step[0][0],step[0][1]]
#
# Input In [6], in ChemEnv.step(self, action, episode_timestep, old_inputs, concs_T_V, prices, bounds)
#      13 def step(self, action,episode_timestep,old_inputs,concs_T_V,prices,bounds): #what we do when we take a step
# ---> 14     new_inputs = simulate_inputs(self.reset,action,episode_timestep,old_inputs, self.T_disturbance, self.Ca_disturbance,bounds)
#      15     k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = new_inputs
#      17     new_concs_T_V = simulate_react(self.reset,episode_timestep,new_inputs,concs_T_V)
#
# Input In [7], in simulate_inputs(reset, action, timestep, inputs, disturbance, disturbance_, bounds)
#      28 k01,DH1,d,Cp,UA,EA1,k02,DH2,EA2,F_in,Ca_in,Cb_in,Tc,Cc_in,F,T_in,Cd_in = inputs
#      31 Ca_in[timestep:] = 1  + disturbance_[timestep]
# ---> 32 Cd_in[timestep:] = min(bounds[2],max(bounds[3], Cd_in[timestep-1:timestep] + action[0]))
#      33 Tc[timestep:] = min(bounds[4],max(bounds[5],Tc[timestep-1:timestep] + (action[1])))
#      34 F_in[timestep:] = min(bounds[0],max(bounds[1],F_in[timestep-1:timestep] + (action[2])))
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\array_ops.py:1096, in _slice_helper(tensor, slice_spec, var)
#    1094   var_empty = constant([], dtype=dtypes.int32)
#    1095   packed_begin = packed_end = packed_strides = var_empty
# -> 1096 return strided_slice(
#    1097     tensor,
#    1098     packed_begin,
#    1099     packed_end,
#    1100     packed_strides,
#    1101     begin_mask=begin_mask,
#    1102     end_mask=end_mask,
#    1103     shrink_axis_mask=shrink_axis_mask,
#    1104     new_axis_mask=new_axis_mask,
#    1105     ellipsis_mask=ellipsis_mask,
#    1106     var=var,
#    1107     name=name)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\array_ops.py:1269, in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1266 if strides is None:
#    1267   strides = ones_like(begin)
# -> 1269 op = gen_array_ops.strided_slice(
#    1270     input=input_,
#    1271     begin=begin,
#    1272     end=end,
#    1273     strides=strides,
#    1274     name=name,
#    1275     begin_mask=begin_mask,
#    1276     end_mask=end_mask,
#    1277     ellipsis_mask=ellipsis_mask,
#    1278     new_axis_mask=new_axis_mask,
#    1279     shrink_axis_mask=shrink_axis_mask)
#    1281 parent_name = name
#    1283 if var is not None:
#
# File ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10671, in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10669 if tld.is_eager:
#   10670   try:
# > 10671     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   10672       _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10673       begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
#   10674       "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10675     return _result
#   10676   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
agent.save_models()
# Out:
# ... saving models ...

# %%
file = open('mltxt.txt', 'w')
file.close()
